# %% [markdown]
# <a href="https://colab.research.google.com/github/denisefss/Mapping_susceptibility_landslides_BH/blob/main/Notebook_ML_landslide_susceptibility_BH_QF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Notebook with machine learning (ML) models for landslide susceptibility: Artificial Neural Network (ANN) and Random Forest (RF) for the QF model of Belo Horizonte (MG) - Brazil**
#
# 1 - landslide occurrence
# 0 - landslide non-occurrence

# %%
# !pip install pyspatialml -q

# %%
from pyspatialml import Raster
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import rasterio.plot
import numpy as np
import matplotlib as mpl
import geopandas as gpd
from tempfile import NamedTemporaryFile
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Setting up the working directory:

# %%
path = '/content/drive/MyDrive/Mapping_susceptibility_landslides_BH/QF'

# %%
os.chdir(path)

# %%
# Provide the full path to the file, replacing '/path/of/file/' with the actual path
data = pd.read_csv('/content/drive/MyDrive/Mapping_susceptibility_landslides_BH/QF/data_aniso.csv', sep=';')

# %%
data.head()
# Out:
#    id       SPI    TPI    TRI       TWI      Slope  Drainage_density  \
# 0   4 -0.027123  0.375  2.375  2.795610  24.331051          4.046961
# 1   5  2.139133 -1.375  3.625  4.214153  36.878178          1.677309
# 2   7  0.544214 -0.125  2.125  3.610038  21.540659          2.310602
# 3   9  1.770607  1.125  3.625  3.771850  37.735924          0.582167
# 4  10  3.203413  0.250  5.500  4.363180  57.271286          0.000000
#
#    Fault_density  Distance_from_drainages  Distance_from_faults  ...  \
# 0       0.002082               176.776695            189.159317  ...
# 1       0.002133               237.500000            100.000000  ...
# 2       0.001731               184.560288             17.677670  ...
# 3       0.001930               127.475488             51.538822  ...
# 4       0.001574               430.479384            139.754242  ...
#
#    Planform_curvature  Use_potential  Profile_curvature  Roughness  \
# 0            0.622703              5          -0.017297        7.0
# 1           -1.867294              5           1.332706       12.0
# 2           -0.308966              5           0.331034        7.0
# 3            1.107416              5          -0.812584       12.0
# 4            0.234146              5          -0.405854       18.0
#
#    Geotechnical_Unit  Road_density         X          Y  Susceptibility  \
# 0                  4      0.047232  616582.0  7797372.0             3.0
# 1                  4      0.058729  617278.0  7797824.0             2.0
# 2                  4      0.041516  614214.0  7795374.0             3.0
# 3                  4      0.033616  614332.0  7794495.0             2.0
# 4                  4      0.080896  610650.0  7793419.0             3.0
#
#    Target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#
# [5 rows x 28 columns]

# %%
data.describe()
# Out:
#                 id          SPI          TPI          TRI          TWI  \
# count  2530.000000  2530.000000  2530.000000  2530.000000  2530.000000
# mean   2596.267194     1.506360     0.021609     2.589505     4.641042
# std    1741.030041     1.680218     0.539202     1.329753     1.821627
# min       4.000000    -7.509858    -1.875000     0.001442     1.941921
# 25%    1059.500000     0.569429    -0.375000     1.500000     3.634212
# 50%    2355.500000     1.621296     0.000000     2.500000     4.278660
# 75%    4059.500000     2.467738     0.375000     3.500000     5.025426
# max    6134.000000    10.343965     2.125000     7.375000    19.093849
#
#              Slope  Drainage_density  Fault_density  Distance_from_drainages  \
# count  2530.000000       2530.000000    2530.000000              2530.000000
# mean     26.820415          1.877826       0.001694               139.649964
# std      14.016736          1.274638       0.000422               110.623658
# min       0.008789          0.000000       0.000556                 0.000000
# 25%      16.000000          0.995778       0.001429                53.033009
# 50%      26.832815          1.760680       0.001689               115.244306
# 75%      36.221542          2.650140       0.001974               197.642354
# max      78.790863          9.778293       0.002537               626.996810
#
#        Distance_from_faults  ...  Planform_curvature  Use_potential  \
# count           2530.000000  ...         2530.000000    2530.000000
# mean             156.342458  ...            0.033215       5.206719
# std              144.293584  ...            0.648621       0.669297
# min                0.000000  ...           -2.080000       2.000000
# 25%               53.750181  ...           -0.408954       5.000000
# 50%              115.244309  ...            0.000000       5.000000
# 75%              212.867325  ...            0.504897       5.000000
# max             1006.618713  ...            2.560000       8.000000
#
#        Profile_curvature    Roughness  Geotechnical_Unit  Road_density  \
# count        2530.000000  2530.000000        2530.000000   2530.000000
# mean           -0.006694     8.535420           3.889723      0.028823
# std             0.636477     4.455714           0.469822      0.034634
# min            -1.974634     0.004395           1.000000      0.000000
# 25%            -0.480000     5.000000           4.000000      0.000000
# 50%             0.000000     8.000000           4.000000      0.000000
# 75%             0.473201    12.000000           4.000000      0.059254
# max             3.174287    26.000000           8.000000      0.187283
#
#                    X             Y  Susceptibility       Target
# count    2530.000000  2.530000e+03     1547.000000  2530.000000
# mean   610718.238898  7.792946e+06        2.296057     0.638340
# std      5323.558037  3.899668e+03        0.845965     0.480576
# min    599679.939600  7.781713e+06        1.000000     0.000000
# 25%    605939.825575  7.789756e+06        2.000000     0.000000
# 50%    610857.006750  7.794279e+06        2.000000     1.000000
# 75%    614844.997950  7.795803e+06        3.000000     1.000000
# max    618192.000000  7.798641e+06        5.000000     1.000000
#
# [8 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['id', 'SPI', 'TPI', 'TRI', 'TWI', 'Slope', 'Drainage_density',
#        'Fault_density', 'Distance_from_drainages', 'Distance_from_faults',
#        'Distance_to_roads', 'Elevation', 'Flow_Accumulation', 'Lithology',
#        'Kinematic_model', 'NDVI', 'Aspect', 'Soils', 'Planform_curvature',
#        'Use_potential', 'Profile_curvature', 'Roughness', 'Geotechnical_Unit',
#        'Road_density', 'X', 'Y', 'Susceptibility', 'Target'],
#       dtype='object')

# %%
#Checking the number of classes in each column
for column in data.columns:
 num_classes = data[column].nunique()
 print(f'The number of unique classes in column {column} is: {num_classes}')
# Out:
# The number of unique classes in column id is: 2530
# The number of unique classes in column SPI is: 1554
# The number of unique classes in column TPI is: 230
# The number of unique classes in column TRI is: 250
# The number of unique classes in column TWI is: 1640
# The number of unique classes in column Slope is: 238
# The number of unique classes in column Drainage_density is: 1855
# The number of unique classes in column Fault_density is: 2041
# The number of unique classes in column Distance_from_drainages is: 320
# The number of unique classes in column Distance_from_faults is: 408
# The number of unique classes in column Distance_to_roads is: 290
# The number of unique classes in column Elevation is: 520
# The number of unique classes in column Flow_Accumulation is: 165
# The number of unique classes in column Lithology is: 14
# The number of unique classes in column Kinematic_model is: 2
# The number of unique classes in column NDVI is: 2046
# The number of unique classes in column Aspect is: 8
# The number of unique classes in column Soils is: 4
# The number of unique classes in column Planform_curvature is: 792
# The number of unique classes in column Use_potential is: 4
# The number of unique classes in column Profile_curvature is: 799
# The number of unique classes in column Roughness is: 134
# The number of unique classes in column Geotechnical_Unit is: 4
# The number of unique classes in column Road_density is: 880
# The number of unique classes in column X is: 2073
# The number of unique classes in column Y is: 2064
# The number of unique classes in column Susceptibility is: 5
# The number of unique classes in column Target is: 2

# %%
# Presenting only the variables to be used in the model (RF Notebook 2 - study of variables).

# Selecting only the desired variables
selected_variables = ['SPI', 'TWI', 'Slope', 'Distance_from_drainages',
                      'Distance_from_faults', 'Elevation',
                      'Lithology', 'Aspect', 'Planform_curvature',
                      'Profile_curvature', 'Target']

# Creating the new DataFrame df with the selected variables
df = data[selected_variables].copy()

# Displaying the first few rows of the DataFrame df for verification
print(df.head())
# Out:
#         SPI       TWI      Slope  Distance_from_drainages  \
# 0 -0.027123  2.795610  24.331051               176.776695
# 1  2.139133  4.214153  36.878178               237.500000
# 2  0.544214  3.610038  21.540659               184.560288
# 3  1.770607  3.771850  37.735924               127.475488
# 4  3.203413  4.363180  57.271286               430.479384
#
#    Distance_from_faults  Elevation  Lithology  Aspect  Planform_curvature  \
# 0            189.159317      902.0          3       7            0.622703
# 1            100.000000      868.0          3       2           -1.867294
# 2             17.677670      968.0          3       3           -0.308966
# 3             51.538822     1131.0          6       8            1.107416
# 4            139.754242      993.0          3       8            0.234146
#
#    Profile_curvature  Target
# 0          -0.017297       1
# 1           1.332706       1
# 2           0.331034       1
# 3          -0.812584       1
# 4          -0.405854       1

# %%
df.columns
# Out:
# Index(['SPI', 'TWI', 'Slope', 'Distance_from_drainages',
#        'Distance_from_faults', 'Elevation', 'Lithology', 'Aspect',
#        'Planform_curvature', 'Profile_curvature', 'Target'],
#       dtype='object')

# %%
predictors = ['SPI.tif', 'TWI.tif', 'Slope.tif', 'Distance_from_drainages.tif','Distance_from_faults.tif', 'Elevation.tif',
              'Lithology.tif', 'Aspect.tif', 'Planform_curvature.tif','Profile_curvature.tif']

# %%
predictors
# Out:
# ['SPI.tif',
#  'TWI.tif',
#  'Slope.tif',
#  'Distance_from_drainages.tif',
#  'Distance_from_faults.tif',
#  'Elevation.tif',
#  'Lithology.tif',
#  'Aspect.tif',
#  'Planform_curvature.tif',
#  'Profile_curvature.tif']

# %%
stack = Raster(predictors)

# %%
stack.names
# Out:
# dict_keys(['SPI', 'TWI', 'Slope', 'Distance_from_drainages', 'Distance_from_faults', 'Elevation', 'Lithology', 'Aspect', 'Planform_curvature', 'Profile_curvature'])

# %%
stack = stack.intersect()

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as ticker

# Choosing a different color palette (e.g. 'viridis')
cmap = 'viridis'
axs = stack.plot(figsize=(12,9), cmap=cmap)

# Iterating over each Axes object to set label formatters
for ax in axs.flatten():
    ax.xaxis.set_major_locator(ticker.MaxNLocator(2))  # Show only 2 ticks on the x-axis
    ax.yaxis.set_major_locator(ticker.MaxNLocator(2))  # Show only 2 ticks on the y-axis
    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
    ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
    ax.tick_params(axis='y', labelrotation=90, labelsize=7)
    ax.tick_params(axis='x', labelsize=7)

# Adjusting the color bar
ax = axs.flatten()[2]
im = ax.images[0]
im.set_clim(0, 90)

# AAdjusting the color bar
ax = axs.flatten()[3]
im = ax.images[0]
im.set_clim(0, 600)

# Adjusting the color bar
ax = axs.flatten()[4]
im = ax.images[0]
im.set_clim(0, 500)

# Adjusting the color bar
ax = axs.flatten()[5]
im = ax.images[0]
im.set_clim(600, 1400)

# Adjusting the color bar
ax = axs.flatten()[6]
im = ax.images[0]
im.set_clim(0, 18)

# Adjusting the color bar
ax = axs.flatten()[7]
im = ax.images[0]
im.set_clim(1, 9)

# Adjusting the color bar
ax = axs.flatten()[8]
im = ax.images[0]
im.set_clim(-1, 1)

# Adjusting the color bar
ax = axs.flatten()[9]
im = ax.images[0]
im.set_clim(-1, 1)

plt.tight_layout()
plt.show()

# %%
print(type(stack))
# Out:
# <class 'pyspatialml.raster.Raster'>

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.ticker as ticker

# Defining a dictionary with the specified color palettes
cmap_dict = {
    'SPI': 'magma',
    'TWI': 'viridis',
    'Slope': 'RdYlGn_r',
    'Distance_from_drainages': 'Blues',
    'Distance_from_faults': 'Reds',
    'Elevation': 'terrain',
    'Lithology': 'viridis',
    'Aspect': 'gist_rainbow',
    'Planform_curvature': 'coolwarm',
    'Profile_curvature': 'coolwarm'
}

# Iterating over each Axes object to define the label formatters
for ax in axs.flatten():
    ax.xaxis.set_major_locator(ticker.MaxNLocator(2))
    ax.yaxis.set_major_locator(ticker.MaxNLocator(2))
    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
    ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
    ax.tick_params(axis='y', labelrotation=90, labelsize=7)
    ax.tick_params(axis='x', labelsize=7)

# Plotting with specified color palettes
fig, axs = plt.subplots(2, 5, figsize=(12, 7))

# Iterating over each column and applying the specific color palette
for ax, (column, cmap) in zip(axs.flatten(), cmap_dict.items()):
    im = stack[column].plot(ax=ax, cmap=cmap)
    ax.xaxis.set_major_locator(ticker.MaxNLocator(2))
    ax.yaxis.set_major_locator(ticker.MaxNLocator(2))
    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
    ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:.0f}"))
    ax.tick_params(axis='y', labelrotation=90, labelsize=7)
    ax.tick_params(axis='x', labelsize=7)

# Adjusting the color bar as needed
clim_dict = {
    'SPI': (-4,4),
    'TWI': (0,20),
    'Slope': (0, 45),
    'Distance_from_drainages': (0, 500),
    'Distance_from_faults': (0, 600),
    'Elevation': (600, 1400),
    'Lithology': (0, 18),
    'Aspect': (1, 9),
    'Planform_curvature': (-1, 1),
    'Profile_curvature': (-1, 1)
}

# Applying color bar limits to each plot
for ax, column in zip(axs.flatten(), clim_dict.keys()):
    im = ax.images[0]
    im.set_clim(*clim_dict[column])

plt.tight_layout()
plt.show()

# %%
# Checking for null values ​​in data2
null_values = df.isnull()

# Checking if there is at least one null value in the entire DataFrame
has_nulls = null_values.any().any()

if has_nulls:
 print("\nThe DataFrame contains null values.")
else:
 print("\nThe DataFrame does not contain null values.")
# Out:
# The DataFrame does not contain null values.

# %%
# Count the number of lines where the values ​​are -9999 or -99999
count_minus_9999 = (df == -9999).any(axis=1).sum()
count_minus_99999 = (df == -99999).any(axis=1).sum()

# Print the results
print(f'Number of lines with -9999: {count_minus_9999}')
print(f'Number of lines with -99999: {count_minus_99999}')

# Remove rows with values ​​-9999 or -99999 and remove missing values
df = df[(df != -9999).all(axis=1) & (df != -99999).all(axis=1)].dropna()
# Out:
# Number of lines with -9999: 0
# Number of lines with -99999: 0

# %%
list(stack.names)
# Out:
# ['SPI',
#  'TWI',
#  'Slope',
#  'Distance_from_drainages',
#  'Distance_from_faults',
#  'Elevation',
#  'Lithology',
#  'Aspect',
#  'Planform_curvature',
#  'Profile_curvature']

# %%
X = df.loc[:, stack.names]

# %%
X.columns
# Out:
# Index(['SPI', 'TWI', 'Slope', 'Distance_from_drainages',
#        'Distance_from_faults', 'Elevation', 'Lithology', 'Aspect',
#        'Planform_curvature', 'Profile_curvature'],
#       dtype='object')

# %%
# Get the column names (variable names)
variable_names = df.columns.tolist()

# Print the index of each variable (numeric position)
for i, variable in enumerate(variable_names):
  print(f"Index of {variable}: {i}")
# Out:
# Index of SPI: 0
# Index of TWI: 1
# Index of Slope: 2
# Index of Distance_from_drainages: 3
# Index of Distance_from_faults: 4
# Index of Elevation: 5
# Index of Lithology: 6
# Index of Aspect: 7
# Index of Planform_curvature: 8
# Index of Profile_curvature: 9
# Index of Target: 10

# %%
# Get the column names from the DataFrame
df_columns = df.columns.tolist()

# Get the names from stack.names
stack_names = list(stack.names)

# Print a comparison table
print("-" * 60)
print("| Variable Name | DataFrame Index | stack.names Index |")
print("-" * 60)

for i, column in enumerate(df_columns):
    df_index = i
    try:
        stack_index = stack_names.index(column)
    except ValueError:
        stack_index = "Not Found"

    print(f"| {column} | {df_index} | {stack_index} |")
print("-" * 60)
# Out:
# ------------------------------------------------------------
# | Variable Name | DataFrame Index | stack.names Index |
# ------------------------------------------------------------
# | SPI | 0 | 0 |
# | TWI | 1 | 1 |
# | Slope | 2 | 2 |
# | Distance_from_drainages | 3 | 3 |
# | Distance_from_faults | 4 | 4 |
# | Elevation | 5 | 5 |
# | Lithology | 6 | 6 |
# | Aspect | 7 | 7 |
# | Planform_curvature | 8 | 8 |
# | Profile_curvature | 9 | 9 |
# | Target | 10 | Not Found |
# ------------------------------------------------------------

# %%
# To find the indices of categorical variables in the dataset
# Using the categorical_features list, which contains the indexes of the columns corresponding to the categorical variables.

var1_idx = list(stack.names).index("Aspect")
var2_idx = list(stack.names).index("Lithology")

print(var1_idx,var2_idx)
# Out:
# 7 6

# %%
#Check Index of categorical variables in dataset
categorical_features = [6, 7]

# %%
X.columns[categorical_features]
# Out:
# Index(['Lithology', 'Aspect'], dtype='object')

# %%
# #Check Index of numeric variables in dataset
numerical_features = [0, 1, 2, 3, 4, 5, 8, 9]

# %%
X.columns[numerical_features]
# Out:
# Index(['SPI', 'TWI', 'Slope', 'Distance_from_drainages',
#        'Distance_from_faults', 'Elevation', 'Planform_curvature',
#        'Profile_curvature'],
#       dtype='object')

# %%
# Select only numeric columns specified in numerical_features
data_num = X[X.columns[numerical_features]]

# Number of variables per line
vars_per_row = 4

# Calculate the number of lines
num_rows = (len(data_num.columns) - 1) // vars_per_row + 1

# Create a figure with subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=vars_per_row, figsize=(12, 8))

# Flatten the axis matrix to facilitate iteration
axes = axes.flatten()

# Create a boxplot for each variable and add it to the corresponding subplot
for i, column in enumerate(data_num):
 ax = axes[i] # Select the correct axis
 ax.boxplot(data_num[column], patch_artist=True, notch=True,
 flierprops=dict(alpha=0.7, marker='o', markersize=4, markerfacecolor='red', markeredgecolor='black'),
 boxprops=dict(linewidth=0.5, facecolor=(0, 0.6, 0.7, 0.7)),
 medianprops=dict(color='yellow', linewidth=2),
 whiskerprops=dict(color='black', linewidth=1))
 ax.set_title('{}'.format(column)) # Chart title
 ax.set_ylabel('Values') # Y-axis label
 ax.set_xticklabels([]) # Remove x-axis labels
 ax.set_xticks([]) # Remove lines from x axis

# Remove unused subplots
for i in range(len(data_num.columns), num_rows * vars_per_row):
 fig.delaxes(axes[i])

# Add title to figure
fig.suptitle('Boxplots of Numerical Variables', fontsize=16)

plt.tight_layout() # Adjust layout to avoid overlapping
plt.show() # Display the boxplots in two lines, I want to leave only the y axis line (values) showing

# %%
data_num.head()
# Out:
#         SPI       TWI      Slope  Distance_from_drainages  \
# 0 -0.027123  2.795610  24.331051               176.776695
# 1  2.139133  4.214153  36.878178               237.500000
# 2  0.544214  3.610038  21.540659               184.560288
# 3  1.770607  3.771850  37.735924               127.475488
# 4  3.203413  4.363180  57.271286               430.479384
#
#    Distance_from_faults  Elevation  Planform_curvature  Profile_curvature
# 0            189.159317      902.0            0.622703          -0.017297
# 1            100.000000      868.0           -1.867294           1.332706
# 2             17.677670      968.0           -0.308966           0.331034
# 3             51.538822     1131.0            1.107416          -0.812584
# 4            139.754242      993.0            0.234146          -0.405854

# %%
# Filter NaN values ​​before plotting histograms
data_num_no_nan = data_num.dropna(subset=data_num.columns[data_num.columns != 'Target'], how='any')

# Number of columns and lines of subplots
num_cols = 4
num_rows = int(np.ceil(len(data_num_no_nan.columns) / num_cols))

# Plot histograms in subplots
plt.figure(figsize=(16, 6))
for i, column in enumerate(data_num_no_nan.columns):
  if column != 'Target':
    plt.subplot(num_rows, num_cols, i+1)
    sns.histplot(data_num_no_nan[column], bins=25, color='lightseagreen')
    ax.set_xticklabels([]) # Remove x-axis labels
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Define numerical column indices and the target column name
numerical_indices = [0, 1, 2, 3, 4, 5, 8, 9]
numerical_columns = [df.columns[i] for i in numerical_indices]
target_column = df.columns[10]

# Number of variables per row
vars_per_row = 4

# Calculate number of rows needed
num_rows = (len(numerical_columns) - 1) // vars_per_row + 1

# Create a figure with subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=vars_per_row, figsize=(10,5))

# Flatten the axes matrix for easier iteration
axes = axes.flatten()

# Create a boxplot for each variable and add to the corresponding subplot
for i, column in enumerate(numerical_columns):
    ax = axes[i]  # Select the correct axis
    sns.boxplot(x=target_column, y=column, data=df, ax=ax, notch=True,
                palette={'0': 'lightblue', '1': 'lightgreen'})
    ax.set_title(f'{column}')  # Title of the plot
    ax.set_ylabel('Values')  # Y-axis label
    ax.set_xlabel('')  # Remove x-axis label
    ax.xaxis.set_visible(False)  # Hide x-axis line
    ax.spines['top'].set_visible(False)  # Hide top border
    ax.spines['right'].set_visible(False)  # Hide right border
    ax.spines['bottom'].set_visible(False)  # Hide bottom border
    ax.spines['left'].set_visible(True)  # Show left border
    ax.yaxis.grid(True)  # Add gridlines to y-axis

# Remove unused subplots
for i in range(len(numerical_columns), num_rows * vars_per_row):
    fig.delaxes(axes[i])

# Add a title to the figure
#fig.suptitle('Boxplots of Numerical Variables by Target', fontsize=16)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to avoid overlap and leave space for the title
plt.show()

# %%
# Counting for Aspect
aspect_counts = df.groupby(['Aspect', 'Target']).size().unstack(fill_value=0)

# Counting for Lithology
litho_counts = df.groupby(['Lithology', 'Target']).size().unstack(fill_value=0)

# Setting the figure size
plt.figure(figsize=(10, 2.5))

# Bar plot for Aspect
plt.subplot(1, 2, 1)  # Subplot for Aspect
bar_width = 0.3
labels_aspect = aspect_counts.index
x_aspect = np.arange(len(labels_aspect))

bars0_aspect = plt.bar(x_aspect - bar_width/2, aspect_counts[0], width=bar_width, label='Non-landslide', color='lightblue')
bars1_aspect = plt.bar(x_aspect + bar_width/2, aspect_counts[1], width=bar_width, label='Landslide', color='lightgreen')

plt.title('Aspect')
plt.ylabel('Count')
plt.xticks(x_aspect, labels_aspect)
#plt.legend()

# Adding counts above the bars in the Aspect plot
for bar in bars0_aspect + bars1_aspect:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{int(yval)}', ha='center', va='bottom', color='black', fontsize=6.5)

# Bar plot for Lithology
plt.subplot(1, 2, 2)  # Subplot for Lithology
bar_width = 0.3
labels_litho = litho_counts.index
x_litho = np.arange(len(labels_litho))

bars0_litho = plt.bar(x_litho - bar_width/2, litho_counts[0], width=bar_width, label='Non-landslide', color='lightblue')
bars1_litho = plt.bar(x_litho + bar_width/2, litho_counts[1], width=bar_width, label='Landslide', color='lightgreen')

plt.title('Lithology')
plt.ylabel('Count')
plt.xticks(x_litho, labels_litho)
plt.legend()

# Adding counts above the bars in the Lithology plot
for bar in bars0_litho + bars1_litho:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{int(yval)}', ha='center', va='bottom', color='black', fontsize=6.5)
# Adjusting layout and displaying the plots
plt.tight_layout()
plt.show()

# %%
# Calculation of descriptive statistics
stats2 = df.groupby(target_column)[numerical_columns].agg(['mean', 'std', 'var'])

# Print the descriptive statistics
print(stats2)
# Out:
#              SPI                           TWI                          Slope  \
#             mean       std       var      mean       std       var       mean
# Target
# 0       1.123057  1.960576  3.843860  5.043582  1.999109  3.996437  19.152184
# 1       1.723526  1.454774  2.116369  4.412978  1.671066  2.792463  31.164955
#
#                               Distance_from_drainages  ...  \
#               std         var                    mean  ...
# Target                                                 ...
# 0       11.382144  129.553194              148.796866  ...
# 1       13.500456  182.262315              134.467663  ...
#
#        Distance_from_faults    Elevation                            \
#                         var         mean         std           var
# Target
# 0              33439.921410  1036.444138  126.310993  15954.467020
# 1              11362.052857   961.351510   60.933038   3712.835114
#
#        Planform_curvature                     Profile_curvature            \
#                      mean       std       var              mean       std
# Target
# 0                0.013913  0.569724  0.324586          0.011856  0.603928
# 1                0.044151  0.689256  0.475074         -0.017204  0.654150
#
#
#              var
# Target
# 0       0.364729
# 1       0.427912
#
# [2 rows x 24 columns]

# %%
# Descriptive statistics for categorical variables

# Count for Aspect
aspect_counts = df.groupby(['Aspect', target_column]).size().unstack(fill_value=0)
aspect_freq = df['Aspect'].value_counts(normalize=True).rename('frequency')

# Count for Lithology
litho_counts = df.groupby(['Lithology', target_column]).size().unstack(fill_value=0)
litho_freq = df['Lithology'].value_counts(normalize=True).rename('frequency')

# Print the categorical descriptive statistics
print("\nCount of Aspect by Target:")
print(aspect_counts)
print("\nRelative frequency of Aspect:")
print(aspect_freq)

print("\nCount of Lithology by Target:")
print(litho_counts)
print("\nRelative frequency of Lithology:")
print(litho_freq)
# Out:
# Count of Aspect by Target:
# Target    0    1
# Aspect
# 1       152  325
# 2       116  283
# 3       100  183
# 4        67  153
# 5        68   58
# 6        79  111
# 7       152  200
# 8       181  302
#
# Relative frequency of Aspect:
# Aspect
# 8    0.190909
# 1    0.188538
# 2    0.157708
# 7    0.139130
# 3    0.111858
# 4    0.086957
# 6    0.075099
# 5    0.049802
# Name: frequency, dtype: float64
#
# Count of Lithology by Target:
# Target       0     1
# Lithology
# 0            1    13
# 1           89    55
# 2            1     8
# 3          561  1431
# 4            7     0
# 5            8     0
# 6           19    38
# 7           65    44
# 8           28     0
# 9          127     5
# 10           6     0
# 11           1     1
# 15           1     5
# 17           1    15
#
# Relative frequency of Lithology:
# Lithology
# 3     0.787352
# 1     0.056917
# 9     0.052174
# 7     0.043083
# 6     0.022530
# 8     0.011067
# 17    0.006324
# 0     0.005534
# 2     0.003557
# 5     0.003162
# 4     0.002767
# 15    0.002372
# 10    0.002372
# 11    0.000791
# Name: frequency, dtype: float64

# %%
df.columns
# Out:
# Index(['SPI', 'TWI', 'Slope', 'Distance_from_drainages',
#        'Distance_from_faults', 'Elevation', 'Lithology', 'Aspect',
#        'Planform_curvature', 'Profile_curvature', 'Target'],
#       dtype='object')

# %%
# Calculate the statistics
stats = pd.DataFrame({
    'Number of Data Points': df.count(),
    'Missing Data': df.isnull().sum(),
    'Mean': df.mean(),
    'Standard Deviation': df.std(),
    'Variance': df.var(),
    'Minimum Value': df.min(),
    '1st Quartile': df.quantile(0.25),
    'Median': df.median(),
    '3rd Quartile': df.quantile(0.75),
    'Maximum Value': df.max(),
    'Mode': df.mode().iloc[0],
    'Mode Frequency': df.apply(lambda x: x.value_counts().max())
})

# Display the statistics table
stats
# Out:
#                          Number of Data Points  Missing Data        Mean  \
# SPI                                       2530             0    1.506360
# TWI                                       2530             0    4.641042
# Slope                                     2530             0   26.820415
# Distance_from_drainages                   2530             0  139.649964
# Distance_from_faults                      2530             0  156.342458
# Elevation                                 2530             0  988.509516
# Lithology                                 2530             0    3.623320
# Aspect                                    2530             0    4.388142
# Planform_curvature                        2530             0    0.033215
# Profile_curvature                         2530             0   -0.006694
# Target                                    2530             0    0.638340
#
#                          Standard Deviation      Variance  Minimum Value  \
# SPI                                1.680218      2.823134      -7.509858
# TWI                                1.821627      3.318325       1.941921
# Slope                             14.016736    196.468875       0.008789
# Distance_from_drainages          110.623658  12237.593612       0.000000
# Distance_from_faults             144.293584  20820.638297       0.000000
# Elevation                         97.148907   9437.910185     788.000000
# Lithology                          2.169017      4.704636       0.000000
# Aspect                             2.636007      6.948535       1.000000
# Planform_curvature                 0.648621      0.420710      -2.080000
# Profile_curvature                  0.636477      0.405103      -1.974634
# Target                             0.480576      0.230953       0.000000
#
#                          1st Quartile      Median  3rd Quartile  \
# SPI                          0.569429    1.621296      2.467738
# TWI                          3.634212    4.278660      5.025426
# Slope                       16.000000   26.832815     36.221542
# Distance_from_drainages     53.033009  115.244306    197.642354
# Distance_from_faults        53.750181  115.244309    212.867325
# Elevation                  927.268814  973.000000   1018.000000
# Lithology                    3.000000    3.000000      3.000000
# Aspect                       2.000000    4.000000      7.000000
# Planform_curvature          -0.408954    0.000000      0.504897
# Profile_curvature           -0.480000    0.000000      0.473201
# Target                       0.000000    1.000000      1.000000
#
#                          Maximum Value        Mode  Mode Frequency
# SPI                          10.343965   -1.015516              14
# TWI                          19.093849    3.777122              14
# Slope                        78.790863   12.649111              83
# Distance_from_drainages     626.996810   12.500000             139
# Distance_from_faults       1006.618713   12.500000             113
# Elevation                  1487.000000  988.000000              28
# Lithology                    17.000000    3.000000            1992
# Aspect                        8.000000    8.000000             483
# Planform_curvature            2.560000    0.000000             367
# Profile_curvature             3.174287    0.000000             274
# Target                        1.000000    1.000000            1615

# %% [markdown]
# Importing packages for Machine Learning

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(categories='auto', handle_unknown='ignore'), categorical_features),
        ('num', StandardScaler(), numerical_features)])

# %%
X[:3]
# Out:
#         SPI       TWI      Slope  Distance_from_drainages  \
# 0 -0.027123  2.795610  24.331051               176.776695
# 1  2.139133  4.214153  36.878178               237.500000
# 2  0.544214  3.610038  21.540659               184.560288
#
#    Distance_from_faults  Elevation  Lithology  Aspect  Planform_curvature  \
# 0            189.159317      902.0          3       7            0.622703
# 1            100.000000      868.0          3       2           -1.867294
# 2             17.677670      968.0          3       3           -0.308966
#
#    Profile_curvature
# 0          -0.017297
# 1           1.332706
# 2           0.331034

# %%
y = df["Target"]

# %%
y[:]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2525    0
# 2526    0
# 2527    0
# 2528    0
# 2529    0
# Name: Target, Length: 2530, dtype: int64

# %% [markdown]
# Splitting our data into a training set (70% of the data) and a test set (30%), stratified after classes, to obtain the same amount of landslide and non-landslide samples in both sets. Random_sate= 42 for reproducibility

# %%
from sklearn.model_selection import train_test_split

# Splitting data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
# Indices of training and test rows in X
train_indices = X_train.index
test_indices = X_test.index

# Selecting corresponding data in df
df_train = df.loc[train_indices]
df_test = df.loc[test_indices]

print("Training Data:")
print(df_train)
print("\Test Data:")
print(df_test)
# Out:
# Training Data:
#            SPI       TWI      Slope  Distance_from_drainages  \
# 65    0.967555  3.188293  34.176014               106.800047
# 518  -0.569209  4.714056   8.000000               112.500000
# 889   1.611832  4.375650  26.832815                50.000000
# 790   2.586377  4.075926  46.818798               132.876823
# 556   1.452335  3.514674  34.409302                75.000000
# ...        ...       ...        ...                      ...
# 1571  0.544214  3.610038  21.540659               190.804219
# 800  -0.037362  2.805807  24.000000                62.500000
# 192   1.309952  2.846775  45.607018               267.219479
# 496   2.514502  4.414384  37.947330               332.133256
# 1950  0.705005  3.449933  25.298222                75.000000
#
#       Distance_from_faults  Elevation  Lithology  Aspect  Planform_curvature  \
# 65              280.902557      981.0          3       1            0.245479
# 518             274.146393      912.0          3       7            0.000000
# 889             348.658142      819.0          1       2           -0.512000
# 790              90.138779      898.0          3       3           -0.028029
# 556              37.500000     1026.0          3       2           -0.640000
# ...                    ...        ...        ...     ...                 ...
# 1571            135.208176      935.0          3       7           -0.088276
# 800              51.538822      868.0          3       3            1.280000
# 192             209.538177      976.0          3       7           -0.721231
# 496             194.454361     1000.0          3       1            0.640000
# 1950            341.412506      949.0          3       7            0.000000
#
#       Profile_curvature  Target
# 65            -0.394521       1
# 518            0.000000       1
# 889            0.128000       1
# 790           -0.668029       1
# 556            0.640000       1
# ...                 ...     ...
# 1571           0.551724       1
# 800            0.000000       1
# 192            0.558769       1
# 496           -0.640000       1
# 1950           0.000000       0
#
# [1771 rows x 11 columns]
# \Test Data:
#            SPI       TWI      Slope  Distance_from_drainages  \
# 319   2.261763  4.091848  40.000000               150.519932
# 2390  4.689511  8.348444  16.000000               273.004121
# 1679 -0.074947  2.843233  24.331051                62.500000
# 872   2.557044  5.181644  28.284271               212.132034
# 713   0.735318  3.419738  28.000000                25.000000
# ...        ...       ...        ...                      ...
# 2344 -0.792861  3.556649  11.313708               257.694102
# 395  -0.971806  3.733880   8.910231                62.500000
# 600   1.626395  3.341061  43.081318               139.754249
# 1401  5.165729  7.703015  28.284271               185.825859
# 1534  1.663467  3.878684  32.984844               135.208173
#
#       Distance_from_faults  Elevation  Lithology  Aspect  Planform_curvature  \
# 319              72.886902      885.0          3       4            0.000000
# 2390            252.796860     1010.0          3       3           -1.280000
# 1679            185.825867      827.0          3       7            0.674595
# 872             190.394333      968.0          3       8           -0.480000
# 713               0.000000     1030.0          7       3            0.000000
# ...                    ...        ...        ...     ...                 ...
# 2344            350.223144      913.0          3       2            1.280000
# 395             221.500565      974.0          0       6            0.636302
# 600             222.556168      933.0          3       7            0.000000
# 1401            141.421356     1032.0          3       7           -0.729600
# 1534            150.519928      897.0          3       1            0.000000
#
#       Profile_curvature  Target
# 319            0.000000       1
# 2390           0.000000       0
# 1679           0.034595       0
# 872            0.800000       1
# 713            0.640000       1
# ...                 ...     ...
# 2344          -1.280000       0
# 395            0.005091       1
# 600            0.000000       1
# 1401           0.550400       1
# 1534           0.000000       1
#
# [759 rows x 11 columns]

# %%
# Count of classes in the training set
counts = np.bincount(y)
print("Distribution of classes in the total set:")
print(f"Target 0: {counts[0]} examples")
print(f"Target 1: {counts[1]} examples")

# Count of classes in the training set
counts_train = np.bincount(y_train)
print("\nDistribution of classes in the training set:")
print(f"Target 0: {counts_train[0]} examples")
print(f"Target: {counts_train[1]} examples")

# Count of classes in the test suite
counts_test = np.bincount(y_test)
print("\nDistribution of classes in the test set:")
print(f"Target 0: {counts_test[0]} examples")
print(f"Target 1: {counts_test[1]} examples")
# Out:
# Distribution of classes in the total set:
# Target 0: 915 examples
# Target 1: 1615 examples
#
# Distribution of classes in the training set:
# Target 0: 640 examples
# Target: 1131 examples
#
# Distribution of classes in the test set:
# Target 0: 275 examples
# Target 1: 484 examples

# %% [markdown]
# Checking the number of points in testing and training data

# %%
X_train.shape
# Out:
# (1771, 10)

# %%
X_train[:3]
# Out:
#           SPI       TWI      Slope  Distance_from_drainages  \
# 65   0.967555  3.188293  34.176014               106.800047
# 518 -0.569209  4.714056   8.000000               112.500000
# 889  1.611832  4.375650  26.832815                50.000000
#
#      Distance_from_faults  Elevation  Lithology  Aspect  Planform_curvature  \
# 65             280.902557      981.0          3       1            0.245479
# 518            274.146393      912.0          3       7            0.000000
# 889            348.658142      819.0          1       2           -0.512000
#
#      Profile_curvature
# 65           -0.394521
# 518           0.000000
# 889           0.128000

# %%
X_test.shape
# Out:
# (759, 10)

# %%
X_test[:3]
# Out:
#            SPI       TWI      Slope  Distance_from_drainages  \
# 319   2.261763  4.091848  40.000000               150.519932
# 2390  4.689511  8.348444  16.000000               273.004121
# 1679 -0.074947  2.843233  24.331051                62.500000
#
#       Distance_from_faults  Elevation  Lithology  Aspect  Planform_curvature  \
# 319              72.886902      885.0          3       4            0.000000
# 2390            252.796860     1010.0          3       3           -1.280000
# 1679            185.825867      827.0          3       7            0.674595
#
#       Profile_curvature
# 319            0.000000
# 2390           0.000000
# 1679           0.034595

# %%
X_train.describe()
# Out:
#                SPI          TWI        Slope  Distance_from_drainages  \
# count  1771.000000  1771.000000  1771.000000              1771.000000
# mean      1.469544     4.637650    26.882302               139.542941
# std       1.704648     1.848075    14.263267               111.695543
# min      -7.509858     2.017691     0.008789                 0.000000
# 25%       0.511364     3.625376    16.000000                52.285914
# 50%       1.609150     4.259337    26.832815               115.244306
# 75%       2.448015     5.031282    36.878178               197.642354
# max       9.772466    18.461983    78.790863               626.996810
#
#        Distance_from_faults    Elevation    Lithology       Aspect  \
# count           1771.000000  1771.000000  1771.000000  1771.000000
# mean             154.038251   987.310949     3.635799     4.470356
# std              144.196776    96.501423     2.188063     2.648440
# min                0.000000   788.000000     0.000000     1.000000
# 25%               53.033009   927.512543     3.000000     2.000000
# 50%              115.244309   971.000000     3.000000     4.000000
# 75%              212.500000  1018.000000     3.000000     7.000000
# max             1006.618713  1487.000000    17.000000     8.000000
#
#        Planform_curvature  Profile_curvature
# count         1771.000000        1771.000000
# mean             0.036950          -0.011242
# std              0.667462           0.652355
# min             -2.080000          -1.939200
# 25%             -0.424999          -0.482462
# 50%              0.000000           0.000000
# 75%              0.512000           0.494514
# max              2.560000           3.174287

# %% [markdown]
# # Visualizing training and testing data

# %%
# Create boxplots for each column of the DataFrame
boxplot_train = X_train.boxplot(patch_artist=True, notch=True, flierprops=dict(alpha=0.7,marker='o', markersize=4, markerfacecolor='red', markeredgecolor='black'),
 boxprops=dict(linewidth=0.5, facecolor=(0, 0.6, 0.7, 0.7)), medianprops=dict(color='yellow', linewidth=2),
 whiskerprops=dict(color='black', linewidth=1), grid=dict(alpha=0.7, color='gray', linewidth=0.1))

# Configure axis title and labels
plt.title('Train data boxplots')
plt.xlabel('Variables')
plt.ylabel('Values')

# Increase the spacing between variables on the x-axis and decrease the font size
plt.xticks(rotation=45, fontsize=8)

# Configure the x-axis size
plt.gcf().set_size_inches(14, 4) # Adjust values ​​(width, height) as needed

# Configure the y-axis in logarithmic scale
plt.yscale('symlog', linthresh=10, linscale=1)

# Set y-axis limits
plt.ylim(-10, 10000)

# Display the graph
plt.show()

# %%
# Set the number of subplots per line
subplots_per_row = 5

# Calculate the number of lines needed
num_rows = (len(X_train.columns) + subplots_per_row - 1) // subplots_per_row

# Create histograms for each variable in X_train
fig, axs = plt.subplots(nrows=num_rows, ncols=subplots_per_row, figsize=(15, 3*num_rows))

# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.5, wspace=0.5)

# Create histograms
for i, column in enumerate(X_train.columns):
 ax = axs[i // subplots_per_row, i % subplots_per_row]
 sns.histplot(X_train[column], bins=20, facecolor=(0, 0.6, 0.7, 0.7), ax=ax, alpha = 0.7)
 ax.set_ylabel('Frequency')

# Remove empty subplots, if any
for i in range(len(X_train.columns), num_rows*subplots_per_row):
 fig.delaxes(axs.flatten()[i])

plt.show()

# %%
# Create boxplots for each column of the DataFrame
boxplot_test = X_test.boxplot(patch_artist=True, notch=True, flierprops=dict(alpha=0.7,marker='o', markersize=4, markerfacecolor='red', markeredgecolor='black'),
 boxprops=dict(linewidth=0.5, facecolor=(0, 0.6, 0.7, 0.7)), medianprops=dict(color='yellow', linewidth=2),
 whiskerprops=dict(color='black', linewidth=1), grid=dict(alpha=0.7, color='gray', linewidth=0.1))

# Configure axis title and labels
plt.title('Test data boxplots')
plt.xlabel('Variables')
plt.ylabel('Values')

# Increase the spacing between variables on the x-axis and decrease the font size
plt.xticks(rotation=45, fontsize=8)

# Configure the x-axis size
plt.gcf().set_size_inches(14, 4) # Adjust values ​​(width, height) as needed
# Configure the y-axis in logarithmic scale
plt.yscale('symlog', linthresh=10, linscale=1)

# Set y-axis limits
plt.ylim(-10, 10000)

# Display the graph
plt.show()

# %%
# Set the number of subplots per line
subplots_per_row = 5

# Calculate the number of lines needed
num_rows = (len(X_test.columns) + subplots_per_row - 1) // subplots_per_row

# Create histograms for each variable in X_test
fig, axs = plt.subplots(nrows=num_rows, ncols=subplots_per_row, figsize=(15, 3*num_rows))

# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.5, wspace=0.5)

# Create histograms
for i, column in enumerate(X_test.columns):
 ax = axs[i // subplots_per_row, i % subplots_per_row]
 sns.histplot(X_test[column], bins=20, facecolor=(0, 0.6, 0.7, 0.7), ax=ax, alpha = 0.7)
 ax.set_ylabel('Frequency')

# Remove empty subplots, if any
for i in range(len(X_test.columns), num_rows*subplots_per_row):
 fig.delaxes(axs.flatten()[i])

plt.show()

# %% [markdown]
# # Artificial neural networks (ANN)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, make_scorer, accuracy_score, cohen_kappa_score, classification_report
from sklearn.model_selection import cross_validate, KFold, GridSearchCV
from sklearn.datasets import load_digits

# %%
'''
# Set the parameters for grid search
# Note: Divide the grid search into more parts if it is too complex

grid_ann = {
    'classifier__hidden_layer_sizes': [(50,), (100,), (100, 50), (100, 100), (100, 100, 100), (20,100), (20,30,100), (7), (10), (11), (12), (13), (15),(16), (18),  (22), (23), (25), (21),(26), (27), (28) ,(29), (33), (34), (35), (36)],
    'classifier__activation': ['relu', 'tanh', 'logistic'],
    'classifier__alpha': [0.0001, 0.00001, 0.000001],
    'classifier__solver': ['adam', 'sgd'],
    'classifier__verbose': [True],
}
'''
# Out:
# "\n# Set the parameters for grid search\n# Note: Divide the grid search into more parts if it is too complex\n\ngrid_ann = {\n    'classifier__hidden_layer_sizes': [(50,), (100,), (100, 50), (100, 100), (100, 100, 100), (20,100), (20,30,100), (7), (10), (11), (12), (13), (15),(16), (18),  (22), (23), (25), (21),(26), (27), (28) ,(29), (33), (34), (35), (36)],\n    'classifier__activation': ['relu', 'tanh', 'logistic'],\n    'classifier__alpha': [0.0001, 0.00001, 0.000001],\n    'classifier__solver': ['adam', 'sgd'],\n    'classifier__verbose': [True],\n}\n"

# %%
# Fit the ColumnTransformer to your data
preprocessor.fit(X_train)

# Transform the training data
X_train_transformed = preprocessor.transform(X_train)

# Get the names of columns after transformation
transformed_columns = preprocessor.get_feature_names_out()

# Get the number of columns after transformation
num_columns_transformed = X_train_transformed.shape[1]

# Display the number of columns after transformation
print("Number of columns after transformation:", num_columns_transformed)

# Display the names of transformed columns
print("Names of columns after transformation:")
print(transformed_columns)

# Fit the ColumnTransformer to your test data
preprocessor.fit(X_test)

# Transform the test data
X_test_transformed = preprocessor.transform(X_test)

# Get the names of columns after transformation for test data
transformed_columns_test = preprocessor.get_feature_names_out()

# Get the number of columns after transformation for test data
num_columns_transformed_test = X_test_transformed.shape[1]

# Display the number of columns after transformation for test data
print("Number of columns after transformation (test data):", num_columns_transformed_test)

# Display the names of transformed columns for test data
print("Names of columns after transformation (test data):")
print(transformed_columns_test)
# Out:
# Number of columns after transformation: 30
# Names of columns after transformation:
# ['cat__Lithology_0' 'cat__Lithology_1' 'cat__Lithology_2'
#  'cat__Lithology_3' 'cat__Lithology_4' 'cat__Lithology_5'
#  'cat__Lithology_6' 'cat__Lithology_7' 'cat__Lithology_8'
#  'cat__Lithology_9' 'cat__Lithology_10' 'cat__Lithology_11'
#  'cat__Lithology_15' 'cat__Lithology_17' 'cat__Aspect_1' 'cat__Aspect_2'
#  'cat__Aspect_3' 'cat__Aspect_4' 'cat__Aspect_5' 'cat__Aspect_6'
#  'cat__Aspect_7' 'cat__Aspect_8' 'num__SPI' 'num__TWI' 'num__Slope'
#  'num__Distance_from_drainages' 'num__Distance_from_faults'
#  'num__Elevation' 'num__Planform_curvature' 'num__Profile_curvature']
# Number of columns after transformation (test data): 28
# Names of columns after transformation (test data):
# ['cat__Lithology_0' 'cat__Lithology_1' 'cat__Lithology_2'
#  'cat__Lithology_3' 'cat__Lithology_5' 'cat__Lithology_6'
#  'cat__Lithology_7' 'cat__Lithology_8' 'cat__Lithology_9'
#  'cat__Lithology_10' 'cat__Lithology_15' 'cat__Lithology_17'
#  'cat__Aspect_1' 'cat__Aspect_2' 'cat__Aspect_3' 'cat__Aspect_4'
#  'cat__Aspect_5' 'cat__Aspect_6' 'cat__Aspect_7' 'cat__Aspect_8'
#  'num__SPI' 'num__TWI' 'num__Slope' 'num__Distance_from_drainages'
#  'num__Distance_from_faults' 'num__Elevation' 'num__Planform_curvature'
#  'num__Profile_curvature']

# %%
# Create a base classifier
base_ann = MLPClassifier(max_iter=1500, verbose=True, tol=0.0001, random_state=42)

# %% [markdown]
# "Pipeline" is for making workflow with standardization and classification in a few lines of code

# %%
# Create the model pipeline
ann_flow = Pipeline([
    ('preproc', preprocessor),
    ('classifier', base_ann)
])

# %%
# Define the acc_scorer metric
acc_scorer = make_scorer(accuracy_score)

# %%
# Initialize KFold cross-validation with 10 folds, shuffling data, and setting random state to 42
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
# Grid search parameters defined for the model
grid_ann = {
    'classifier__hidden_layer_sizes': [(28,)],  # Single hidden layer with 28 neurons
    'classifier__activation': ['relu'],         # Activation function ReLU
    'classifier__alpha': [0.1],                 # Regularization parameter alpha
    'classifier__solver': ['adam'],             # Optimizer solver Adam
}

# %%
model_ann = GridSearchCV(ann_flow, param_grid = grid_ann, cv = kfold, scoring=acc_scorer)

# %%
model_ann.fit(X_train, y_train)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Iteration 42, loss = 0.41865579
# Iteration 43, loss = 0.41744505
# Iteration 44, loss = 0.41629847
# Iteration 45, loss = 0.41522235
# Iteration 46, loss = 0.41416238
# Iteration 47, loss = 0.41312216
# Iteration 48, loss = 0.41223197
# Iteration 49, loss = 0.41115982
# Iteration 50, loss = 0.41032772
# Iteration 51, loss = 0.40936861
# Iteration 52, loss = 0.40852354
# Iteration 53, loss = 0.40769694
# Iteration 54, loss = 0.40691357
# Iteration 55, loss = 0.40613805
# Iteration 56, loss = 0.40533480
# Iteration 57, loss = 0.40477051
# Iteration 58, loss = 0.40384310
# Iteration 59, loss = 0.40319217
# Iteration 60, loss = 0.40245053
# Iteration 61, loss = 0.40178117
# Iteration 62, loss = 0.40108322
# Iteration 63, loss = 0.40036503
# Iteration 64, loss = 0.39975406
# Iteration 65, loss = 0.39896480
# Iteration 66, loss = 0.39833312
# Iteration 67, loss = 0.39769882
# Iteration 68, loss = 0.39707931
# Iteration 69, loss = 0.39641243
# Iteration 70, loss = 0.39584292
# Iteration 71, loss = 0.39520073
# Iteration 72, loss = 0.39472327
# Iteration 73, loss = 0.39401750
# Iteration 74, loss = 0.39348558
# Iteration 75, loss = 0.39284661
# Iteration 76, loss = 0.39220808
# Iteration 77, loss = 0.39163133
# Iteration 78, loss = 0.39121437
# Iteration 79, loss = 0.39069205
# Iteration 80, loss = 0.39012531
# Iteration 81, loss = 0.38951208
# Iteration 82, loss = 0.38915097
# Iteration 83, loss = 0.38856983
# Iteration 84, loss = 0.38800249
# Iteration 85, loss = 0.38753841
# Iteration 86, loss = 0.38707803
# Iteration 87, loss = 0.38662136
# Iteration 88, loss = 0.38604213
# Iteration 89, loss = 0.38559160
# Iteration 90, loss = 0.38530992
# Iteration 91, loss = 0.38468046
# Iteration 92, loss = 0.38424057
# Iteration 93, loss = 0.38377271
# Iteration 94, loss = 0.38333581
# Iteration 95, loss = 0.38292813
# Iteration 96, loss = 0.38258740
# Iteration 97, loss = 0.38200344
# Iteration 98, loss = 0.38148802
# Iteration 99, loss = 0.38113077
# Iteration 100, loss = 0.38075484
# Iteration 101, loss = 0.38023130
# Iteration 102, loss = 0.37987813
# Iteration 103, loss = 0.37979185
# Iteration 104, loss = 0.37916597
# Iteration 105, loss = 0.37875825
# Iteration 106, loss = 0.37821741
# Iteration 107, loss = 0.37781027
# Iteration 108, loss = 0.37753793
# Iteration 109, loss = 0.37716965
# Iteration 110, loss = 0.37677420
# Iteration 111, loss = 0.37653988
# Iteration 112, loss = 0.37602907
# Iteration 113, loss = 0.37565198
# Iteration 114, loss = 0.37515256
# Iteration 115, loss = 0.37491203
# Iteration 116, loss = 0.37442923
# Iteration 117, loss = 0.37400752
# Iteration 118, loss = 0.37377988
# Iteration 119, loss = 0.37334743
# Iteration 120, loss = 0.37303796
# Iteration 121, loss = 0.37267447
# Iteration 122, loss = 0.37229990
# Iteration 123, loss = 0.37204197
# Iteration 124, loss = 0.37161906
# Iteration 125, loss = 0.37130523
# Iteration 126, loss = 0.37091583
# Iteration 127, loss = 0.37060888
# Iteration 128, loss = 0.37031540
# Iteration 129, loss = 0.37003109
# Iteration 130, loss = 0.36965765
# Iteration 131, loss = 0.36949819
# Iteration 132, loss = 0.36902202
# Iteration 133, loss = 0.36865008
# Iteration 134, loss = 0.36845412
# Iteration 135, loss = 0.36808241
# Iteration 136, loss = 0.36783981
# Iteration 137, loss = 0.36750480
# Iteration 138, loss = 0.36728274
# Iteration 139, loss = 0.36689852
# Iteration 140, loss = 0.36650602
# Iteration 141, loss = 0.36632605
# Iteration 142, loss = 0.36606663
# Iteration 143, loss = 0.36570177
# Iteration 144, loss = 0.36541350
# Iteration 145, loss = 0.36513526
# Iteration 146, loss = 0.36504199
# Iteration 147, loss = 0.36458930
# Iteration 148, loss = 0.36444676
# Iteration 149, loss = 0.36408118
# Iteration 150, loss = 0.36382795
# Iteration 151, loss = 0.36354625
# Iteration 152, loss = 0.36325866
# Iteration 153, loss = 0.36309028
# Iteration 154, loss = 0.36274983
# Iteration 155, loss = 0.36247291
# Iteration 156, loss = 0.36226061
# Iteration 157, loss = 0.36196766
# Iteration 158, loss = 0.36176706
# Iteration 159, loss = 0.36151437
# Iteration 160, loss = 0.36125753
# Iteration 161, loss = 0.36101780
# Iteration 162, loss = 0.36063402
# Iteration 163, loss = 0.36061352
# Iteration 164, loss = 0.36049215
# Iteration 165, loss = 0.36016538
# Iteration 166, loss = 0.35961055
# Iteration 167, loss = 0.35957270
# Iteration 168, loss = 0.35929593
# Iteration 169, loss = 0.35914335
# Iteration 170, loss = 0.35874851
# Iteration 171, loss = 0.35851413
# Iteration 172, loss = 0.35837718
# Iteration 173, loss = 0.35804633
# Iteration 174, loss = 0.35772011
# Iteration 175, loss = 0.35747921
# Iteration 176, loss = 0.35737332
# Iteration 177, loss = 0.35704442
# Iteration 178, loss = 0.35683007
# Iteration 179, loss = 0.35659825
# Iteration 180, loss = 0.35635321
# Iteration 181, loss = 0.35638130
# Iteration 182, loss = 0.35585079
# Iteration 183, loss = 0.35569558
# Iteration 184, loss = 0.35543039
# Iteration 185, loss = 0.35518737
# Iteration 186, loss = 0.35507476
# Iteration 187, loss = 0.35469812
# Iteration 188, loss = 0.35445636
# Iteration 189, loss = 0.35431034
# Iteration 190, loss = 0.35421851
# Iteration 191, loss = 0.35383807
# Iteration 192, loss = 0.35374298
# Iteration 193, loss = 0.35342170
# Iteration 194, loss = 0.35328477
# Iteration 195, loss = 0.35310645
# Iteration 196, loss = 0.35304961
# Iteration 197, loss = 0.35289350
# Iteration 198, loss = 0.35255982
# Iteration 199, loss = 0.35224488
# Iteration 200, loss = 0.35207169
# Iteration 201, loss = 0.35187712
# Iteration 202, loss = 0.35164382
# Iteration 203, loss = 0.35144560
# Iteration 204, loss = 0.35122465
# Iteration 205, loss = 0.35101216
# Iteration 206, loss = 0.35077576
# Iteration 207, loss = 0.35071227
# Iteration 208, loss = 0.35030056
# Iteration 209, loss = 0.35031602
# Iteration 210, loss = 0.35003662
# Iteration 211, loss = 0.34989316
# Iteration 212, loss = 0.34961016
# Iteration 213, loss = 0.34943995
# Iteration 214, loss = 0.34930365
# Iteration 215, loss = 0.34901500
# Iteration 216, loss = 0.34896330
# Iteration 217, loss = 0.34860567
# Iteration 218, loss = 0.34843799
# Iteration 219, loss = 0.34828079
# Iteration 220, loss = 0.34812561
# Iteration 221, loss = 0.34783588
# Iteration 222, loss = 0.34779079
# Iteration 223, loss = 0.34746221
# Iteration 224, loss = 0.34726316
# Iteration 225, loss = 0.34707623
# Iteration 226, loss = 0.34694783
# Iteration 227, loss = 0.34678659
# Iteration 228, loss = 0.34662958
# Iteration 229, loss = 0.34638862
# Iteration 230, loss = 0.34613179
# Iteration 231, loss = 0.34605155
# Iteration 232, loss = 0.34581828
# Iteration 233, loss = 0.34561192
# Iteration 234, loss = 0.34549446
# Iteration 235, loss = 0.34538413
# Iteration 236, loss = 0.34514508
# Iteration 237, loss = 0.34517531
# Iteration 238, loss = 0.34491895
# Iteration 239, loss = 0.34464531
# Iteration 240, loss = 0.34452697
# Iteration 241, loss = 0.34439694
# Iteration 242, loss = 0.34416404
# Iteration 243, loss = 0.34383501
# Iteration 244, loss = 0.34375953
# Iteration 245, loss = 0.34350610
# Iteration 246, loss = 0.34337025
# Iteration 247, loss = 0.34315348
# Iteration 248, loss = 0.34293130
# Iteration 249, loss = 0.34289647
# Iteration 250, loss = 0.34273891
# Iteration 251, loss = 0.34270470
# Iteration 252, loss = 0.34227468
# Iteration 253, loss = 0.34217184
# Iteration 254, loss = 0.34193584
# Iteration 255, loss = 0.34189369
# Iteration 256, loss = 0.34179486
# Iteration 257, loss = 0.34134921
# Iteration 258, loss = 0.34118591
# Iteration 259, loss = 0.34120821
# Iteration 260, loss = 0.34084807
# Iteration 261, loss = 0.34079315
# Iteration 262, loss = 0.34063565
# Iteration 263, loss = 0.34041564
# Iteration 264, loss = 0.34031148
# Iteration 265, loss = 0.34029475
# Iteration 266, loss = 0.33991062
# Iteration 267, loss = 0.33973589
# Iteration 268, loss = 0.33970448
# Iteration 269, loss = 0.33938688
# Iteration 270, loss = 0.33933090
# Iteration 271, loss = 0.33914309
# Iteration 272, loss = 0.33899328
# Iteration 273, loss = 0.33867679
# Iteration 274, loss = 0.33850952
# Iteration 275, loss = 0.33844326
# Iteration 276, loss = 0.33821654
# Iteration 277, loss = 0.33816869
# Iteration 278, loss = 0.33782960
# Iteration 279, loss = 0.33774529
# Iteration 280, loss = 0.33769016
# Iteration 281, loss = 0.33737444
# Iteration 282, loss = 0.33729190
# Iteration 283, loss = 0.33729017
# Iteration 284, loss = 0.33696656
# Iteration 285, loss = 0.33675882
# Iteration 286, loss = 0.33687842
# Iteration 287, loss = 0.33644497
# Iteration 288, loss = 0.33670331
# Iteration 289, loss = 0.33616046
# Iteration 290, loss = 0.33618305
# Iteration 291, loss = 0.33581935
# Iteration 292, loss = 0.33573448
# Iteration 293, loss = 0.33571306
# Iteration 294, loss = 0.33546061
# Iteration 295, loss = 0.33525359
# Iteration 296, loss = 0.33511109
# Iteration 297, loss = 0.33494751
# Iteration 298, loss = 0.33482432
# Iteration 299, loss = 0.33453222
# Iteration 300, loss = 0.33449580
# Iteration 301, loss = 0.33437987
# Iteration 302, loss = 0.33428607
# Iteration 303, loss = 0.33401677
# Iteration 304, loss = 0.33394245
# Iteration 305, loss = 0.33369898
# Iteration 306, loss = 0.33364086
# Iteration 307, loss = 0.33368272
# Iteration 308, loss = 0.33343627
# Iteration 309, loss = 0.33337160
# Iteration 310, loss = 0.33319189
# Iteration 311, loss = 0.33299570
# Iteration 312, loss = 0.33281968
# Iteration 313, loss = 0.33278141
# Iteration 314, loss = 0.33264471
# Iteration 315, loss = 0.33255967
# Iteration 316, loss = 0.33274655
# Iteration 317, loss = 0.33224362
# Iteration 318, loss = 0.33222141
# Iteration 319, loss = 0.33204451
# Iteration 320, loss = 0.33183832
# Iteration 321, loss = 0.33182957
# Iteration 322, loss = 0.33172054
# Iteration 323, loss = 0.33145448
# Iteration 324, loss = 0.33145051
# Iteration 325, loss = 0.33131255
# Iteration 326, loss = 0.33117728
# Iteration 327, loss = 0.33118848
# Iteration 328, loss = 0.33081248
# Iteration 329, loss = 0.33101060
# Iteration 330, loss = 0.33056516
# Iteration 331, loss = 0.33063752
# Iteration 332, loss = 0.33042727
# Iteration 333, loss = 0.33039726
# Iteration 334, loss = 0.33011714
# Iteration 335, loss = 0.32992604
# Iteration 336, loss = 0.32997187
# Iteration 337, loss = 0.33004373
# Iteration 338, loss = 0.32955361
# Iteration 339, loss = 0.32952518
# Iteration 340, loss = 0.32946219
# Iteration 341, loss = 0.32927770
# Iteration 342, loss = 0.32909281
# Iteration 343, loss = 0.32926147
# Iteration 344, loss = 0.32893914
# Iteration 345, loss = 0.32904650
# Iteration 346, loss = 0.32861881
# Iteration 347, loss = 0.32867754
# Iteration 348, loss = 0.32850787
# Iteration 349, loss = 0.32846191
# Iteration 350, loss = 0.32828395
# Iteration 351, loss = 0.32803331
# Iteration 352, loss = 0.32811952
# Iteration 353, loss = 0.32824355
# Iteration 354, loss = 0.32790863
# Iteration 355, loss = 0.32757074
# Iteration 356, loss = 0.32755971
# Iteration 357, loss = 0.32755306
# Iteration 358, loss = 0.32728769
# Iteration 359, loss = 0.32725641
# Iteration 360, loss = 0.32709630
# Iteration 361, loss = 0.32696857
# Iteration 362, loss = 0.32678176
# Iteration 363, loss = 0.32685932
# Iteration 364, loss = 0.32660158
# Iteration 365, loss = 0.32649611
# Iteration 366, loss = 0.32639226
# Iteration 367, loss = 0.32646837
# Iteration 368, loss = 0.32646010
# Iteration 369, loss = 0.32624109
# Iteration 370, loss = 0.32605418
# Iteration 371, loss = 0.32611051
# Iteration 372, loss = 0.32582251
# Iteration 373, loss = 0.32576470
# Iteration 374, loss = 0.32544463
# Iteration 375, loss = 0.32530261
# Iteration 376, loss = 0.32538408
# Iteration 377, loss = 0.32526852
# Iteration 378, loss = 0.32509383
# Iteration 379, loss = 0.32494680
# Iteration 380, loss = 0.32487073
# Iteration 381, loss = 0.32476599
# Iteration 382, loss = 0.32462069
# Iteration 383, loss = 0.32467147
# Iteration 384, loss = 0.32452330
# Iteration 385, loss = 0.32440608
# Iteration 386, loss = 0.32432420
# Iteration 387, loss = 0.32437542
# Iteration 388, loss = 0.32419929
# Iteration 389, loss = 0.32409064
# Iteration 390, loss = 0.32394022
# Iteration 391, loss = 0.32377635
# Iteration 392, loss = 0.32363398
# Iteration 393, loss = 0.32381943
# Iteration 394, loss = 0.32355241
# Iteration 395, loss = 0.32349875
# Iteration 396, loss = 0.32309130
# Iteration 397, loss = 0.32353299
# Iteration 398, loss = 0.32308017
# Iteration 399, loss = 0.32319020
# Iteration 400, loss = 0.32283023
# Iteration 401, loss = 0.32312719
# Iteration 402, loss = 0.32267212
# Iteration 403, loss = 0.32251839
# Iteration 404, loss = 0.32239528
# Iteration 405, loss = 0.32228144
# Iteration 406, loss = 0.32215176
# Iteration 407, loss = 0.32232616
# Iteration 408, loss = 0.32205022
# Iteration 409, loss = 0.32197216
# Iteration 410, loss = 0.32189554
# Iteration 411, loss = 0.32170639
# Iteration 412, loss = 0.32154182
# Iteration 413, loss = 0.32144003
# Iteration 414, loss = 0.32158066
# Iteration 415, loss = 0.32133909
# Iteration 416, loss = 0.32141522
# Iteration 417, loss = 0.32107604
# Iteration 418, loss = 0.32109797
# Iteration 419, loss = 0.32111217
# Iteration 420, loss = 0.32098135
# Iteration 421, loss = 0.32074483
# Iteration 422, loss = 0.32056943
# Iteration 423, loss = 0.32042897
# Iteration 424, loss = 0.32041024
# Iteration 425, loss = 0.32044297
# Iteration 426, loss = 0.32035981
# Iteration 427, loss = 0.32005014
# Iteration 428, loss = 0.31990270
# Iteration 429, loss = 0.31979032
# Iteration 430, loss = 0.31965489
# Iteration 431, loss = 0.31972612
# Iteration 432, loss = 0.31945426
# Iteration 433, loss = 0.31941059
# Iteration 434, loss = 0.31947877
# Iteration 435, loss = 0.31928725
# Iteration 436, loss = 0.31904486
# Iteration 437, loss = 0.31906058
# Iteration 438, loss = 0.31905889
# Iteration 439, loss = 0.31908086
# Iteration 440, loss = 0.31880159
# Iteration 441, loss = 0.31894550
# Iteration 442, loss = 0.31863666
# Iteration 443, loss = 0.31835405
# Iteration 444, loss = 0.31841561
# Iteration 445, loss = 0.31840681
# Iteration 446, loss = 0.31839497
# Iteration 447, loss = 0.31831059
# Iteration 448, loss = 0.31802477
# Iteration 449, loss = 0.31850380
# Iteration 450, loss = 0.31796568
# Iteration 451, loss = 0.31781625
# Iteration 452, loss = 0.31768732
# Iteration 453, loss = 0.31768303
# Iteration 454, loss = 0.31752199
# Iteration 455, loss = 0.31772855
# Iteration 456, loss = 0.31765285
# Iteration 457, loss = 0.31728694
# Iteration 458, loss = 0.31715918
# Iteration 459, loss = 0.31717237
# Iteration 460, loss = 0.31694045
# Iteration 461, loss = 0.31685735
# Iteration 462, loss = 0.31678745
# Iteration 463, loss = 0.31668305
# Iteration 464, loss = 0.31677039
# Iteration 465, loss = 0.31659117
# Iteration 466, loss = 0.31651371
# Iteration 467, loss = 0.31640422
# Iteration 468, loss = 0.31624518
# Iteration 469, loss = 0.31608962
# Iteration 470, loss = 0.31619011
# Iteration 471, loss = 0.31605838
# Iteration 472, loss = 0.31590027
# Iteration 473, loss = 0.31572584
# Iteration 474, loss = 0.31564275
# Iteration 475, loss = 0.31560499
# Iteration 476, loss = 0.31552208
# Iteration 477, loss = 0.31548847
# Iteration 478, loss = 0.31551364
# Iteration 479, loss = 0.31541274
# Iteration 480, loss = 0.31522072
# Iteration 481, loss = 0.31505532
# Iteration 482, loss = 0.31498413
# Iteration 483, loss = 0.31506870
# Iteration 484, loss = 0.31501813
# Iteration 485, loss = 0.31478573
# Iteration 486, loss = 0.31488019
# Iteration 487, loss = 0.31447174
# Iteration 488, loss = 0.31469572
# Iteration 489, loss = 0.31442969
# Iteration 490, loss = 0.31441009
# Iteration 491, loss = 0.31436270
# Iteration 492, loss = 0.31417196
# Iteration 493, loss = 0.31410403
# Iteration 494, loss = 0.31394449
# Iteration 495, loss = 0.31389500
# Iteration 496, loss = 0.31373793
# Iteration 497, loss = 0.31384804
# Iteration 498, loss = 0.31398176
# Iteration 499, loss = 0.31372137
# Iteration 500, loss = 0.31338320
# Iteration 501, loss = 0.31326381
# Iteration 502, loss = 0.31331783
# Iteration 503, loss = 0.31312092
# Iteration 504, loss = 0.31322488
# Iteration 505, loss = 0.31311007
# Iteration 506, loss = 0.31322762
# Iteration 507, loss = 0.31298094
# Iteration 508, loss = 0.31284584
# Iteration 509, loss = 0.31273095
# Iteration 510, loss = 0.31258783
# Iteration 511, loss = 0.31284972
# Iteration 512, loss = 0.31250361
# Iteration 513, loss = 0.31263729
# Iteration 514, loss = 0.31247755
# Iteration 515, loss = 0.31268365
# Iteration 516, loss = 0.31268819
# Iteration 517, loss = 0.31235576
# Iteration 518, loss = 0.31199712
# Iteration 519, loss = 0.31195880
# Iteration 520, loss = 0.31192664
# Iteration 521, loss = 0.31185338
# Iteration 522, loss = 0.31163437
# Iteration 523, loss = 0.31173175
# Iteration 524, loss = 0.31148419
# Iteration 525, loss = 0.31136525
# Iteration 526, loss = 0.31145529
# Iteration 527, loss = 0.31118616
# Iteration 528, loss = 0.31116468
# Iteration 529, loss = 0.31123496
# Iteration 530, loss = 0.31092160
# Iteration 531, loss = 0.31088826
# Iteration 532, loss = 0.31073939
# Iteration 533, loss = 0.31067757
# Iteration 534, loss = 0.31070812
# Iteration 535, loss = 0.31057723
# Iteration 536, loss = 0.31057496
# Iteration 537, loss = 0.31038612
# Iteration 538, loss = 0.31041741
# Iteration 539, loss = 0.31035958
# Iteration 540, loss = 0.31014769
# Iteration 541, loss = 0.31019303
# Iteration 542, loss = 0.31016893
# Iteration 543, loss = 0.31026785
# Iteration 544, loss = 0.31030987
# Iteration 545, loss = 0.30985941
# Iteration 546, loss = 0.30987598
# Iteration 547, loss = 0.30955075
# Iteration 548, loss = 0.30949193
# Iteration 549, loss = 0.30952972
# Iteration 550, loss = 0.30946609
# Iteration 551, loss = 0.30973515
# Iteration 552, loss = 0.30945079
# Iteration 553, loss = 0.30929251
# Iteration 554, loss = 0.30899667
# Iteration 555, loss = 0.30892174
# Iteration 556, loss = 0.30867673
# Iteration 557, loss = 0.30860749
# Iteration 558, loss = 0.30856929
# Iteration 559, loss = 0.30851071
# Iteration 560, loss = 0.30828433
# Iteration 561, loss = 0.30830082
# Iteration 562, loss = 0.30812498
# Iteration 563, loss = 0.30833756
# Iteration 564, loss = 0.30815372
# Iteration 565, loss = 0.30814979
# Iteration 566, loss = 0.30782166
# Iteration 567, loss = 0.30771107
# Iteration 568, loss = 0.30776794
# Iteration 569, loss = 0.30751554
# Iteration 570, loss = 0.30758411
# Iteration 571, loss = 0.30747630
# Iteration 572, loss = 0.30717767
# Iteration 573, loss = 0.30725005
# Iteration 574, loss = 0.30717945
# Iteration 575, loss = 0.30695630
# Iteration 576, loss = 0.30696997
# Iteration 577, loss = 0.30688556
# Iteration 578, loss = 0.30678048
# Iteration 579, loss = 0.30669322
# Iteration 580, loss = 0.30672827
# Iteration 581, loss = 0.30638584
# Iteration 582, loss = 0.30641129
# Iteration 583, loss = 0.30618462
# Iteration 584, loss = 0.30656671
# Iteration 585, loss = 0.30628862
# Iteration 586, loss = 0.30612735
# Iteration 587, loss = 0.30640484
# Iteration 588, loss = 0.30611132
# Iteration 589, loss = 0.30564401
# Iteration 590, loss = 0.30568033
# Iteration 591, loss = 0.30565952
# Iteration 592, loss = 0.30583288
# Iteration 593, loss = 0.30536147
# Iteration 594, loss = 0.30540917
# Iteration 595, loss = 0.30534500
# Iteration 596, loss = 0.30503571
# Iteration 597, loss = 0.30529841
# Iteration 598, loss = 0.30504514
# Iteration 599, loss = 0.30506268
# Iteration 600, loss = 0.30518728
# Iteration 601, loss = 0.30472605
# Iteration 602, loss = 0.30463030
# Iteration 603, loss = 0.30478282
# Iteration 604, loss = 0.30441960
# Iteration 605, loss = 0.30437814
# Iteration 606, loss = 0.30431251
# Iteration 607, loss = 0.30426516
# Iteration 608, loss = 0.30442379
# Iteration 609, loss = 0.30422772
# Iteration 610, loss = 0.30405060
# Iteration 611, loss = 0.30395596
# Iteration 612, loss = 0.30372564
# Iteration 613, loss = 0.30385191
# Iteration 614, loss = 0.30381782
# Iteration 615, loss = 0.30368785
# Iteration 616, loss = 0.30365423
# Iteration 617, loss = 0.30376008
# Iteration 618, loss = 0.30333546
# Iteration 619, loss = 0.30330283
# Iteration 620, loss = 0.30323391
# Iteration 621, loss = 0.30321851
# Iteration 622, loss = 0.30314372
# Iteration 623, loss = 0.30304048
# Iteration 624, loss = 0.30286618
# Iteration 625, loss = 0.30279659
# Iteration 626, loss = 0.30280892
# Iteration 627, loss = 0.30266686
# Iteration 628, loss = 0.30262598
# Iteration 629, loss = 0.30264953
# Iteration 630, loss = 0.30251129
# Iteration 631, loss = 0.30253456
# Iteration 632, loss = 0.30244255
# Iteration 633, loss = 0.30252150
# Iteration 634, loss = 0.30225220
# Iteration 635, loss = 0.30229531
# Iteration 636, loss = 0.30224100
# Iteration 637, loss = 0.30212745
# Iteration 638, loss = 0.30218037
# Iteration 639, loss = 0.30203020
# Iteration 640, loss = 0.30180135
# Iteration 641, loss = 0.30201879
# Iteration 642, loss = 0.30182523
# Iteration 643, loss = 0.30186986
# Iteration 644, loss = 0.30167000
# Iteration 645, loss = 0.30160828
# Iteration 646, loss = 0.30129785
# Iteration 647, loss = 0.30127905
# Iteration 648, loss = 0.30119610
# Iteration 649, loss = 0.30113442
# Iteration 650, loss = 0.30116095
# Iteration 651, loss = 0.30108052
# Iteration 652, loss = 0.30098969
# Iteration 653, loss = 0.30080840
# Iteration 654, loss = 0.30072753
# Iteration 655, loss = 0.30093343
# Iteration 656, loss = 0.30042528
# Iteration 657, loss = 0.30051765
# Iteration 658, loss = 0.30040727
# Iteration 659, loss = 0.30043326
# Iteration 660, loss = 0.30020579
# Iteration 661, loss = 0.30031881
# Iteration 662, loss = 0.30025988
# Iteration 663, loss = 0.30014878
# Iteration 664, loss = 0.29989561
# Iteration 665, loss = 0.29988269
# Iteration 666, loss = 0.29978207
# Iteration 667, loss = 0.29980945
# Iteration 668, loss = 0.29976133
# Iteration 669, loss = 0.29982190
# Iteration 670, loss = 0.29949882
# Iteration 671, loss = 0.29930448
# Iteration 672, loss = 0.29935535
# Iteration 673, loss = 0.29934896
# Iteration 674, loss = 0.29920024
# Iteration 675, loss = 0.29916465
# Iteration 676, loss = 0.29907414
# Iteration 677, loss = 0.29920125
# Iteration 678, loss = 0.29908162
# Iteration 679, loss = 0.29906024
# Iteration 680, loss = 0.29878536
# Iteration 681, loss = 0.29892442
# Iteration 682, loss = 0.29865830
# Iteration 683, loss = 0.29840969
# Iteration 684, loss = 0.29847266
# Iteration 685, loss = 0.29830004
# Iteration 686, loss = 0.29851653
# Iteration 687, loss = 0.29865847
# Iteration 688, loss = 0.29828982
# Iteration 689, loss = 0.29832700
# Iteration 690, loss = 0.29799272
# Iteration 691, loss = 0.29806975
# Iteration 692, loss = 0.29808128
# Iteration 693, loss = 0.29786941
# Iteration 694, loss = 0.29780968
# Iteration 695, loss = 0.29795508
# Iteration 696, loss = 0.29781050
# Iteration 697, loss = 0.29751191
# Iteration 698, loss = 0.29745429
# Iteration 699, loss = 0.29735428
# Iteration 700, loss = 0.29733850
# Iteration 701, loss = 0.29733992
# Iteration 702, loss = 0.29727217
# Iteration 703, loss = 0.29706103
# Iteration 704, loss = 0.29740824
# Iteration 705, loss = 0.29708393
# Iteration 706, loss = 0.29711592
# Iteration 707, loss = 0.29699380
# Iteration 708, loss = 0.29724057
# Iteration 709, loss = 0.29696194
# Iteration 710, loss = 0.29687419
# Iteration 711, loss = 0.29663939
# Iteration 712, loss = 0.29668056
# Iteration 713, loss = 0.29658904
# Iteration 714, loss = 0.29661100
# Iteration 715, loss = 0.29688162
# Iteration 716, loss = 0.29642567
# Iteration 717, loss = 0.29640729
# Iteration 718, loss = 0.29631325
# Iteration 719, loss = 0.29642851
# Iteration 720, loss = 0.29632472
# Iteration 721, loss = 0.29613112
# Iteration 722, loss = 0.29624673
# Iteration 723, loss = 0.29588111
# Iteration 724, loss = 0.29615779
# Iteration 725, loss = 0.29579578
# Iteration 726, loss = 0.29590088
# Iteration 727, loss = 0.29585382
# Iteration 728, loss = 0.29548127
# Iteration 729, loss = 0.29575997
# Iteration 730, loss = 0.29556880
# Iteration 731, loss = 0.29549327
# Iteration 732, loss = 0.29544887
# Iteration 733, loss = 0.29554450
# Iteration 734, loss = 0.29507522
# Iteration 735, loss = 0.29511942
# Iteration 736, loss = 0.29512463
# Iteration 737, loss = 0.29493309
# Iteration 738, loss = 0.29511841
# Iteration 739, loss = 0.29498438
# Iteration 740, loss = 0.29491676
# Iteration 741, loss = 0.29479786
# Iteration 742, loss = 0.29468833
# Iteration 743, loss = 0.29468065
# Iteration 744, loss = 0.29466897
# Iteration 745, loss = 0.29459470
# Iteration 746, loss = 0.29451129
# Iteration 747, loss = 0.29439707
# Iteration 748, loss = 0.29435584
# Iteration 749, loss = 0.29426234
# Iteration 750, loss = 0.29437171
# Iteration 751, loss = 0.29427797
# Iteration 752, loss = 0.29414573
# Iteration 753, loss = 0.29417410
# Iteration 754, loss = 0.29447213
# Iteration 755, loss = 0.29383113
# Iteration 756, loss = 0.29401982
# Iteration 757, loss = 0.29405674
# Iteration 758, loss = 0.29393438
# Iteration 759, loss = 0.29393976
# Iteration 760, loss = 0.29370762
# Iteration 761, loss = 0.29361868
# Iteration 762, loss = 0.29357415
# Iteration 763, loss = 0.29347707
# Iteration 764, loss = 0.29371202
# Iteration 765, loss = 0.29358964
# Iteration 766, loss = 0.29339673
# Iteration 767, loss = 0.29344775
# Iteration 768, loss = 0.29322281
# Iteration 769, loss = 0.29329361
# Iteration 770, loss = 0.29310770
# Iteration 771, loss = 0.29319730
# Iteration 772, loss = 0.29292254
# Iteration 773, loss = 0.29299272
# Iteration 774, loss = 0.29298569
# Iteration 775, loss = 0.29279306
# Iteration 776, loss = 0.29304986
# Iteration 777, loss = 0.29277427
# Iteration 778, loss = 0.29252688
# Iteration 779, loss = 0.29257019
# Iteration 780, loss = 0.29254437
# Iteration 781, loss = 0.29247318
# Iteration 782, loss = 0.29237810
# Iteration 783, loss = 0.29247620
# Iteration 784, loss = 0.29222983
# Iteration 785, loss = 0.29240362
# Iteration 786, loss = 0.29227676
# Iteration 787, loss = 0.29245594
# Iteration 788, loss = 0.29252678
# Iteration 789, loss = 0.29199630
# Iteration 790, loss = 0.29221224
# Iteration 791, loss = 0.29216037
# Iteration 792, loss = 0.29258952
# Iteration 793, loss = 0.29199636
# Iteration 794, loss = 0.29184121
# Iteration 795, loss = 0.29163312
# Iteration 796, loss = 0.29192960
# Iteration 797, loss = 0.29151245
# Iteration 798, loss = 0.29163848
# Iteration 799, loss = 0.29158494
# Iteration 800, loss = 0.29155514
# Iteration 801, loss = 0.29157240
# Iteration 802, loss = 0.29145063
# Iteration 803, loss = 0.29144251
# Iteration 804, loss = 0.29139925
# Iteration 805, loss = 0.29117225
# Iteration 806, loss = 0.29140039
# Iteration 807, loss = 0.29107045
# Iteration 808, loss = 0.29096703
# Iteration 809, loss = 0.29101633
# Iteration 810, loss = 0.29111216
# Iteration 811, loss = 0.29098331
# Iteration 812, loss = 0.29078411
# Iteration 813, loss = 0.29097370
# Iteration 814, loss = 0.29072384
# Iteration 815, loss = 0.29062960
# Iteration 816, loss = 0.29067621
# Iteration 817, loss = 0.29088946
# Iteration 818, loss = 0.29075645
# Iteration 819, loss = 0.29059329
# Iteration 820, loss = 0.29062028
# Iteration 821, loss = 0.29033935
# Iteration 822, loss = 0.29055008
# Iteration 823, loss = 0.29062426
# Iteration 824, loss = 0.29036469
# Iteration 825, loss = 0.29044294
# Iteration 826, loss = 0.29046606
# Iteration 827, loss = 0.29022370
# Iteration 828, loss = 0.29012242
# Iteration 829, loss = 0.29022301
# Iteration 830, loss = 0.29020536
# Iteration 831, loss = 0.28997917
# Iteration 832, loss = 0.29008356
# Iteration 833, loss = 0.28985900
# Iteration 834, loss = 0.29019845
# Iteration 835, loss = 0.29017068
# Iteration 836, loss = 0.28969321
# Iteration 837, loss = 0.28990100
# Iteration 838, loss = 0.28972865
# Iteration 839, loss = 0.28949772
# Iteration 840, loss = 0.28954408
# Iteration 841, loss = 0.28982286
# Iteration 842, loss = 0.28953783
# Iteration 843, loss = 0.28938201
# Iteration 844, loss = 0.28945456
# Iteration 845, loss = 0.28951901
# Iteration 846, loss = 0.28963524
# Iteration 847, loss = 0.28920379
# Iteration 848, loss = 0.28938058
# Iteration 849, loss = 0.28928465
# Iteration 850, loss = 0.28923597
# Iteration 851, loss = 0.28911565
# Iteration 852, loss = 0.28904630
# Iteration 853, loss = 0.28895938
# Iteration 854, loss = 0.28890013
# Iteration 855, loss = 0.28890416
# Iteration 856, loss = 0.28910700
# Iteration 857, loss = 0.28895647
# Iteration 858, loss = 0.28892916
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.83625093
# Iteration 2, loss = 0.78865689
# Iteration 3, loss = 0.74814022
# Iteration 4, loss = 0.71100260
# Iteration 5, loss = 0.67887672
# Iteration 6, loss = 0.65099236
# Iteration 7, loss = 0.62536354
# Iteration 8, loss = 0.60331996
# Iteration 9, loss = 0.58353052
# Iteration 10, loss = 0.56618943
# Iteration 11, loss = 0.55030432
# Iteration 12, loss = 0.53637942
# Iteration 13, loss = 0.52399050
# Iteration 14, loss = 0.51270413
# Iteration 15, loss = 0.50287336
# Iteration 16, loss = 0.49422415
# Iteration 17, loss = 0.48631603
# Iteration 18, loss = 0.47958581
# Iteration 19, loss = 0.47370140
# Iteration 20, loss = 0.46838406
# Iteration 21, loss = 0.46356710
# Iteration 22, loss = 0.45945805
# Iteration 23, loss = 0.45574213
# Iteration 24, loss = 0.45243802
# Iteration 25, loss = 0.44917760
# Iteration 26, loss = 0.44654721
# Iteration 27, loss = 0.44394339
# Iteration 28, loss = 0.44153571
# Iteration 29, loss = 0.43934518
# Iteration 30, loss = 0.43731812
# Iteration 31, loss = 0.43559658
# Iteration 32, loss = 0.43380438
# Iteration 33, loss = 0.43222223
# Iteration 34, loss = 0.43062327
# Iteration 35, loss = 0.42916093
# Iteration 36, loss = 0.42777585
# Iteration 37, loss = 0.42646606
# Iteration 38, loss = 0.42512534
# Iteration 39, loss = 0.42395623
# Iteration 40, loss = 0.42279645
# Iteration 41, loss = 0.42162301
# Iteration 42, loss = 0.42061418
# Iteration 43, loss = 0.41942800
# Iteration 44, loss = 0.41840103
# Iteration 45, loss = 0.41744470
# Iteration 46, loss = 0.41641651
# Iteration 47, loss = 0.41555836
# Iteration 48, loss = 0.41458106
# Iteration 49, loss = 0.41371988
# Iteration 50, loss = 0.41281353
# Iteration 51, loss = 0.41206007
# Iteration 52, loss = 0.41119666
# Iteration 53, loss = 0.41045633
# Iteration 54, loss = 0.40954568
# Iteration 55, loss = 0.40884096
# Iteration 56, loss = 0.40811250
# Iteration 57, loss = 0.40753417
# Iteration 58, loss = 0.40662613
# Iteration 59, loss = 0.40590459
# Iteration 60, loss = 0.40529053
# Iteration 61, loss = 0.40455734
# Iteration 62, loss = 0.40375284
# Iteration 63, loss = 0.40312644
# Iteration 64, loss = 0.40239254
# Iteration 65, loss = 0.40175129
# Iteration 66, loss = 0.40117745
# Iteration 67, loss = 0.40050694
# Iteration 68, loss = 0.39974428
# Iteration 69, loss = 0.39908676
# Iteration 70, loss = 0.39858959
# Iteration 71, loss = 0.39798059
# Iteration 72, loss = 0.39739640
# Iteration 73, loss = 0.39680429
# Iteration 74, loss = 0.39636515
# Iteration 75, loss = 0.39568370
# Iteration 76, loss = 0.39516832
# Iteration 77, loss = 0.39474229
# Iteration 78, loss = 0.39418801
# Iteration 79, loss = 0.39358404
# Iteration 80, loss = 0.39315023
# Iteration 81, loss = 0.39269059
# Iteration 82, loss = 0.39229710
# Iteration 83, loss = 0.39177652
# Iteration 84, loss = 0.39127526
# Iteration 85, loss = 0.39074652
# Iteration 86, loss = 0.39034718
# Iteration 87, loss = 0.38987340
# Iteration 88, loss = 0.38942037
# Iteration 89, loss = 0.38896531
# Iteration 90, loss = 0.38864266
# Iteration 91, loss = 0.38803971
# Iteration 92, loss = 0.38762410
# Iteration 93, loss = 0.38721762
# Iteration 94, loss = 0.38673781
# Iteration 95, loss = 0.38643624
# Iteration 96, loss = 0.38588384
# Iteration 97, loss = 0.38556089
# Iteration 98, loss = 0.38514164
# Iteration 99, loss = 0.38470959
# Iteration 100, loss = 0.38424493
# Iteration 101, loss = 0.38397228
# Iteration 102, loss = 0.38352281
# Iteration 103, loss = 0.38319929
# Iteration 104, loss = 0.38269772
# Iteration 105, loss = 0.38255178
# Iteration 106, loss = 0.38199302
# Iteration 107, loss = 0.38165667
# Iteration 108, loss = 0.38116739
# Iteration 109, loss = 0.38107360
# Iteration 110, loss = 0.38059129
# Iteration 111, loss = 0.38011950
# Iteration 112, loss = 0.37978349
# Iteration 113, loss = 0.37946750
# Iteration 114, loss = 0.37921901
# Iteration 115, loss = 0.37871418
# Iteration 116, loss = 0.37843027
# Iteration 117, loss = 0.37803012
# Iteration 118, loss = 0.37767380
# Iteration 119, loss = 0.37736967
# Iteration 120, loss = 0.37705225
# Iteration 121, loss = 0.37679264
# Iteration 122, loss = 0.37641696
# Iteration 123, loss = 0.37609884
# Iteration 124, loss = 0.37571513
# Iteration 125, loss = 0.37539920
# Iteration 126, loss = 0.37504609
# Iteration 127, loss = 0.37478326
# Iteration 128, loss = 0.37449099
# Iteration 129, loss = 0.37430076
# Iteration 130, loss = 0.37388083
# Iteration 131, loss = 0.37365228
# Iteration 132, loss = 0.37344126
# Iteration 133, loss = 0.37302609
# Iteration 134, loss = 0.37273986
# Iteration 135, loss = 0.37246110
# Iteration 136, loss = 0.37217465
# Iteration 137, loss = 0.37196354
# Iteration 138, loss = 0.37155171
# Iteration 139, loss = 0.37134385
# Iteration 140, loss = 0.37101003
# Iteration 141, loss = 0.37081045
# Iteration 142, loss = 0.37056483
# Iteration 143, loss = 0.37027486
# Iteration 144, loss = 0.37001085
# Iteration 145, loss = 0.36968705
# Iteration 146, loss = 0.36946862
# Iteration 147, loss = 0.36919101
# Iteration 148, loss = 0.36903395
# Iteration 149, loss = 0.36870797
# Iteration 150, loss = 0.36852295
# Iteration 151, loss = 0.36827788
# Iteration 152, loss = 0.36802228
# Iteration 153, loss = 0.36770528
# Iteration 154, loss = 0.36743929
# Iteration 155, loss = 0.36724704
# Iteration 156, loss = 0.36689443
# Iteration 157, loss = 0.36659867
# Iteration 158, loss = 0.36644194
# Iteration 159, loss = 0.36621117
# Iteration 160, loss = 0.36593625
# Iteration 161, loss = 0.36558594
# Iteration 162, loss = 0.36539792
# Iteration 163, loss = 0.36525225
# Iteration 164, loss = 0.36495027
# Iteration 165, loss = 0.36461788
# Iteration 166, loss = 0.36449485
# Iteration 167, loss = 0.36424557
# Iteration 168, loss = 0.36410944
# Iteration 169, loss = 0.36376561
# Iteration 170, loss = 0.36343836
# Iteration 171, loss = 0.36320241
# Iteration 172, loss = 0.36304030
# Iteration 173, loss = 0.36288052
# Iteration 174, loss = 0.36279190
# Iteration 175, loss = 0.36248163
# Iteration 176, loss = 0.36207210
# Iteration 177, loss = 0.36197860
# Iteration 178, loss = 0.36169544
# Iteration 179, loss = 0.36155301
# Iteration 180, loss = 0.36109670
# Iteration 181, loss = 0.36105944
# Iteration 182, loss = 0.36077839
# Iteration 183, loss = 0.36074759
# Iteration 184, loss = 0.36035235
# Iteration 185, loss = 0.36024571
# Iteration 186, loss = 0.35994083
# Iteration 187, loss = 0.35996057
# Iteration 188, loss = 0.35967639
# Iteration 189, loss = 0.35943886
# Iteration 190, loss = 0.35926758
# Iteration 191, loss = 0.35918849
# Iteration 192, loss = 0.35881896
# Iteration 193, loss = 0.35864945
# Iteration 194, loss = 0.35841739
# Iteration 195, loss = 0.35847922
# Iteration 196, loss = 0.35821863
# Iteration 197, loss = 0.35797859
# Iteration 198, loss = 0.35778022
# Iteration 199, loss = 0.35756065
# Iteration 200, loss = 0.35732485
# Iteration 201, loss = 0.35710296
# Iteration 202, loss = 0.35699125
# Iteration 203, loss = 0.35688893
# Iteration 204, loss = 0.35653899
# Iteration 205, loss = 0.35650838
# Iteration 206, loss = 0.35625766
# Iteration 207, loss = 0.35604159
# Iteration 208, loss = 0.35611532
# Iteration 209, loss = 0.35593498
# Iteration 210, loss = 0.35552052
# Iteration 211, loss = 0.35526720
# Iteration 212, loss = 0.35503504
# Iteration 213, loss = 0.35497385
# Iteration 214, loss = 0.35472455
# Iteration 215, loss = 0.35467639
# Iteration 216, loss = 0.35473113
# Iteration 217, loss = 0.35435204
# Iteration 218, loss = 0.35409359
# Iteration 219, loss = 0.35390966
# Iteration 220, loss = 0.35394765
# Iteration 221, loss = 0.35355565
# Iteration 222, loss = 0.35324771
# Iteration 223, loss = 0.35316929
# Iteration 224, loss = 0.35289895
# Iteration 225, loss = 0.35272130
# Iteration 226, loss = 0.35278573
# Iteration 227, loss = 0.35253024
# Iteration 228, loss = 0.35228254
# Iteration 229, loss = 0.35209415
# Iteration 230, loss = 0.35202107
# Iteration 231, loss = 0.35233609
# Iteration 232, loss = 0.35184813
# Iteration 233, loss = 0.35166469
# Iteration 234, loss = 0.35125302
# Iteration 235, loss = 0.35117264
# Iteration 236, loss = 0.35106036
# Iteration 237, loss = 0.35083842
# Iteration 238, loss = 0.35067545
# Iteration 239, loss = 0.35049843
# Iteration 240, loss = 0.35036809
# Iteration 241, loss = 0.35034441
# Iteration 242, loss = 0.35002341
# Iteration 243, loss = 0.34993921
# Iteration 244, loss = 0.34988787
# Iteration 245, loss = 0.34972515
# Iteration 246, loss = 0.34960969
# Iteration 247, loss = 0.34953364
# Iteration 248, loss = 0.34913746
# Iteration 249, loss = 0.34919664
# Iteration 250, loss = 0.34891620
# Iteration 251, loss = 0.34879303
# Iteration 252, loss = 0.34866372
# Iteration 253, loss = 0.34852200
# Iteration 254, loss = 0.34833724
# Iteration 255, loss = 0.34815890
# Iteration 256, loss = 0.34803860
# Iteration 257, loss = 0.34788662
# Iteration 258, loss = 0.34796670
# Iteration 259, loss = 0.34756976
# Iteration 260, loss = 0.34755247
# Iteration 261, loss = 0.34745190
# Iteration 262, loss = 0.34728583
# Iteration 263, loss = 0.34721830
# Iteration 264, loss = 0.34687344
# Iteration 265, loss = 0.34681835
# Iteration 266, loss = 0.34696664
# Iteration 267, loss = 0.34662133
# Iteration 268, loss = 0.34638183
# Iteration 269, loss = 0.34647630
# Iteration 270, loss = 0.34613864
# Iteration 271, loss = 0.34614013
# Iteration 272, loss = 0.34579607
# Iteration 273, loss = 0.34587928
# Iteration 274, loss = 0.34565079
# Iteration 275, loss = 0.34542073
# Iteration 276, loss = 0.34528344
# Iteration 277, loss = 0.34520485
# Iteration 278, loss = 0.34528098
# Iteration 279, loss = 0.34494857
# Iteration 280, loss = 0.34492613
# Iteration 281, loss = 0.34465071
# Iteration 282, loss = 0.34459914
# Iteration 283, loss = 0.34427409
# Iteration 284, loss = 0.34426351
# Iteration 285, loss = 0.34436380
# Iteration 286, loss = 0.34399031
# Iteration 287, loss = 0.34372452
# Iteration 288, loss = 0.34395058
# Iteration 289, loss = 0.34372353
# Iteration 290, loss = 0.34338072
# Iteration 291, loss = 0.34346383
# Iteration 292, loss = 0.34332575
# Iteration 293, loss = 0.34306246
# Iteration 294, loss = 0.34276399
# Iteration 295, loss = 0.34293160
# Iteration 296, loss = 0.34260532
# Iteration 297, loss = 0.34255058
# Iteration 298, loss = 0.34221461
# Iteration 299, loss = 0.34216162
# Iteration 300, loss = 0.34211410
# Iteration 301, loss = 0.34203130
# Iteration 302, loss = 0.34192785
# Iteration 303, loss = 0.34157858
# Iteration 304, loss = 0.34138473
# Iteration 305, loss = 0.34126452
# Iteration 306, loss = 0.34109253
# Iteration 307, loss = 0.34099728
# Iteration 308, loss = 0.34082003
# Iteration 309, loss = 0.34101283
# Iteration 310, loss = 0.34042007
# Iteration 311, loss = 0.34027033
# Iteration 312, loss = 0.34033947
# Iteration 313, loss = 0.34013231
# Iteration 314, loss = 0.33989859
# Iteration 315, loss = 0.33983251
# Iteration 316, loss = 0.33947928
# Iteration 317, loss = 0.33956497
# Iteration 318, loss = 0.33936660
# Iteration 319, loss = 0.33920181
# Iteration 320, loss = 0.33941749
# Iteration 321, loss = 0.33892498
# Iteration 322, loss = 0.33875223
# Iteration 323, loss = 0.33855648
# Iteration 324, loss = 0.33858237
# Iteration 325, loss = 0.33817638
# Iteration 326, loss = 0.33811732
# Iteration 327, loss = 0.33799538
# Iteration 328, loss = 0.33804565
# Iteration 329, loss = 0.33771958
# Iteration 330, loss = 0.33756876
# Iteration 331, loss = 0.33733033
# Iteration 332, loss = 0.33737014
# Iteration 333, loss = 0.33708394
# Iteration 334, loss = 0.33704187
# Iteration 335, loss = 0.33672277
# Iteration 336, loss = 0.33673602
# Iteration 337, loss = 0.33655115
# Iteration 338, loss = 0.33637094
# Iteration 339, loss = 0.33628155
# Iteration 340, loss = 0.33629402
# Iteration 341, loss = 0.33585507
# Iteration 342, loss = 0.33584426
# Iteration 343, loss = 0.33560080
# Iteration 344, loss = 0.33582287
# Iteration 345, loss = 0.33532190
# Iteration 346, loss = 0.33523330
# Iteration 347, loss = 0.33508436
# Iteration 348, loss = 0.33485970
# Iteration 349, loss = 0.33474043
# Iteration 350, loss = 0.33450611
# Iteration 351, loss = 0.33446966
# Iteration 352, loss = 0.33449029
# Iteration 353, loss = 0.33431054
# Iteration 354, loss = 0.33400650
# Iteration 355, loss = 0.33400915
# Iteration 356, loss = 0.33365600
# Iteration 357, loss = 0.33367749
# Iteration 358, loss = 0.33342056
# Iteration 359, loss = 0.33337966
# Iteration 360, loss = 0.33320663
# Iteration 361, loss = 0.33309686
# Iteration 362, loss = 0.33274392
# Iteration 363, loss = 0.33262908
# Iteration 364, loss = 0.33287708
# Iteration 365, loss = 0.33245092
# Iteration 366, loss = 0.33227663
# Iteration 367, loss = 0.33205803
# Iteration 368, loss = 0.33210958
# Iteration 369, loss = 0.33166993
# Iteration 370, loss = 0.33165452
# Iteration 371, loss = 0.33162911
# Iteration 372, loss = 0.33126526
# Iteration 373, loss = 0.33130460
# Iteration 374, loss = 0.33099902
# Iteration 375, loss = 0.33090375
# Iteration 376, loss = 0.33088894
# Iteration 377, loss = 0.33071366
# Iteration 378, loss = 0.33054860
# Iteration 379, loss = 0.33024571
# Iteration 380, loss = 0.33013473
# Iteration 381, loss = 0.32995619
# Iteration 382, loss = 0.32993712
# Iteration 383, loss = 0.32968451
# Iteration 384, loss = 0.32958282
# Iteration 385, loss = 0.32957057
# Iteration 386, loss = 0.32930884
# Iteration 387, loss = 0.32913526
# Iteration 388, loss = 0.32904172
# Iteration 389, loss = 0.32891219
# Iteration 390, loss = 0.32863980
# Iteration 391, loss = 0.32899396
# Iteration 392, loss = 0.32867221
# Iteration 393, loss = 0.32824879
# Iteration 394, loss = 0.32811659
# Iteration 395, loss = 0.32801757
# Iteration 396, loss = 0.32804028
# Iteration 397, loss = 0.32784357
# Iteration 398, loss = 0.32777864
# Iteration 399, loss = 0.32770174
# Iteration 400, loss = 0.32759335
# Iteration 401, loss = 0.32722556
# Iteration 402, loss = 0.32723208
# Iteration 403, loss = 0.32736083
# Iteration 404, loss = 0.32719085
# Iteration 405, loss = 0.32709801
# Iteration 406, loss = 0.32670940
# Iteration 407, loss = 0.32715784
# Iteration 408, loss = 0.32665375
# Iteration 409, loss = 0.32692329
# Iteration 410, loss = 0.32642069
# Iteration 411, loss = 0.32628421
# Iteration 412, loss = 0.32606894
# Iteration 413, loss = 0.32603185
# Iteration 414, loss = 0.32592403
# Iteration 415, loss = 0.32571647
# Iteration 416, loss = 0.32566626
# Iteration 417, loss = 0.32543390
# Iteration 418, loss = 0.32552959
# Iteration 419, loss = 0.32534178
# Iteration 420, loss = 0.32530088
# Iteration 421, loss = 0.32499269
# Iteration 422, loss = 0.32485240
# Iteration 423, loss = 0.32501339
# Iteration 424, loss = 0.32480441
# Iteration 425, loss = 0.32479010
# Iteration 426, loss = 0.32455630
# Iteration 427, loss = 0.32470471
# Iteration 428, loss = 0.32412902
# Iteration 429, loss = 0.32424965
# Iteration 430, loss = 0.32432587
# Iteration 431, loss = 0.32414880
# Iteration 432, loss = 0.32405419
# Iteration 433, loss = 0.32391617
# Iteration 434, loss = 0.32359935
# Iteration 435, loss = 0.32382913
# Iteration 436, loss = 0.32341189
# Iteration 437, loss = 0.32347031
# Iteration 438, loss = 0.32329465
# Iteration 439, loss = 0.32320277
# Iteration 440, loss = 0.32309811
# Iteration 441, loss = 0.32302728
# Iteration 442, loss = 0.32301491
# Iteration 443, loss = 0.32291780
# Iteration 444, loss = 0.32287455
# Iteration 445, loss = 0.32275765
# Iteration 446, loss = 0.32258809
# Iteration 447, loss = 0.32272344
# Iteration 448, loss = 0.32221509
# Iteration 449, loss = 0.32226755
# Iteration 450, loss = 0.32213621
# Iteration 451, loss = 0.32213332
# Iteration 452, loss = 0.32214385
# Iteration 453, loss = 0.32187539
# Iteration 454, loss = 0.32184057
# Iteration 455, loss = 0.32236640
# Iteration 456, loss = 0.32153536
# Iteration 457, loss = 0.32143158
# Iteration 458, loss = 0.32141947
# Iteration 459, loss = 0.32150651
# Iteration 460, loss = 0.32115708
# Iteration 461, loss = 0.32108720
# Iteration 462, loss = 0.32099090
# Iteration 463, loss = 0.32090055
# Iteration 464, loss = 0.32077223
# Iteration 465, loss = 0.32110522
# Iteration 466, loss = 0.32071583
# Iteration 467, loss = 0.32060642
# Iteration 468, loss = 0.32057759
# Iteration 469, loss = 0.32040163
# Iteration 470, loss = 0.32042313
# Iteration 471, loss = 0.32014105
# Iteration 472, loss = 0.32009625
# Iteration 473, loss = 0.31989802
# Iteration 474, loss = 0.31978729
# Iteration 475, loss = 0.31976971
# Iteration 476, loss = 0.31962952
# Iteration 477, loss = 0.31987632
# Iteration 478, loss = 0.31941244
# Iteration 479, loss = 0.31944272
# Iteration 480, loss = 0.31938910
# Iteration 481, loss = 0.31935775
# Iteration 482, loss = 0.31932339
# Iteration 483, loss = 0.31921383
# Iteration 484, loss = 0.31914955
# Iteration 485, loss = 0.31872659
# Iteration 486, loss = 0.31873605
# Iteration 487, loss = 0.31876327
# Iteration 488, loss = 0.31846693
# Iteration 489, loss = 0.31845071
# Iteration 490, loss = 0.31822944
# Iteration 491, loss = 0.31809554
# Iteration 492, loss = 0.31832559
# Iteration 493, loss = 0.31833814
# Iteration 494, loss = 0.31796469
# Iteration 495, loss = 0.31786550
# Iteration 496, loss = 0.31763856
# Iteration 497, loss = 0.31772442
# Iteration 498, loss = 0.31750895
# Iteration 499, loss = 0.31737162
# Iteration 500, loss = 0.31727686
# Iteration 501, loss = 0.31731998
# Iteration 502, loss = 0.31772199
# Iteration 503, loss = 0.31713383
# Iteration 504, loss = 0.31725448
# Iteration 505, loss = 0.31700350
# Iteration 506, loss = 0.31693406
# Iteration 507, loss = 0.31661520
# Iteration 508, loss = 0.31680663
# Iteration 509, loss = 0.31663196
# Iteration 510, loss = 0.31634780
# Iteration 511, loss = 0.31643054
# Iteration 512, loss = 0.31599642
# Iteration 513, loss = 0.31600727
# Iteration 514, loss = 0.31610836
# Iteration 515, loss = 0.31571551
# Iteration 516, loss = 0.31580102
# Iteration 517, loss = 0.31583998
# Iteration 518, loss = 0.31556729
# Iteration 519, loss = 0.31556168
# Iteration 520, loss = 0.31556622
# Iteration 521, loss = 0.31538876
# Iteration 522, loss = 0.31538728
# Iteration 523, loss = 0.31513020
# Iteration 524, loss = 0.31515075
# Iteration 525, loss = 0.31490135
# Iteration 526, loss = 0.31508934
# Iteration 527, loss = 0.31489124
# Iteration 528, loss = 0.31508011
# Iteration 529, loss = 0.31472334
# Iteration 530, loss = 0.31476853
# Iteration 531, loss = 0.31445033
# Iteration 532, loss = 0.31451604
# Iteration 533, loss = 0.31443192
# Iteration 534, loss = 0.31451984
# Iteration 535, loss = 0.31416743
# Iteration 536, loss = 0.31394037
# Iteration 537, loss = 0.31400142
# Iteration 538, loss = 0.31396529
# Iteration 539, loss = 0.31372275
# Iteration 540, loss = 0.31375596
# Iteration 541, loss = 0.31372832
# Iteration 542, loss = 0.31383976
# Iteration 543, loss = 0.31367254
# Iteration 544, loss = 0.31341073
# Iteration 545, loss = 0.31342881
# Iteration 546, loss = 0.31324433
# Iteration 547, loss = 0.31338172
# Iteration 548, loss = 0.31332364
# Iteration 549, loss = 0.31319525
# Iteration 550, loss = 0.31305921
# Iteration 551, loss = 0.31293422
# Iteration 552, loss = 0.31261185
# Iteration 553, loss = 0.31280963
# Iteration 554, loss = 0.31256133
# Iteration 555, loss = 0.31281304
# Iteration 556, loss = 0.31268674
# Iteration 557, loss = 0.31231333
# Iteration 558, loss = 0.31231826
# Iteration 559, loss = 0.31236740
# Iteration 560, loss = 0.31196463
# Iteration 561, loss = 0.31217250
# Iteration 562, loss = 0.31192927
# Iteration 563, loss = 0.31174988
# Iteration 564, loss = 0.31193165
# Iteration 565, loss = 0.31180435
# Iteration 566, loss = 0.31181795
# Iteration 567, loss = 0.31141539
# Iteration 568, loss = 0.31169328
# Iteration 569, loss = 0.31133542
# Iteration 570, loss = 0.31150329
# Iteration 571, loss = 0.31136333
# Iteration 572, loss = 0.31129684
# Iteration 573, loss = 0.31117268
# Iteration 574, loss = 0.31088310
# Iteration 575, loss = 0.31098775
# Iteration 576, loss = 0.31075304
# Iteration 577, loss = 0.31057814
# Iteration 578, loss = 0.31075692
# Iteration 579, loss = 0.31069536
# Iteration 580, loss = 0.31081204
# Iteration 581, loss = 0.31041139
# Iteration 582, loss = 0.31040539
# Iteration 583, loss = 0.31041832
# Iteration 584, loss = 0.31015005
# Iteration 585, loss = 0.31006787
# Iteration 586, loss = 0.31012040
# Iteration 587, loss = 0.31034862
# Iteration 588, loss = 0.30981997
# Iteration 589, loss = 0.30966697
# Iteration 590, loss = 0.30988349
# Iteration 591, loss = 0.31003175
# Iteration 592, loss = 0.30962387
# Iteration 593, loss = 0.30978893
# Iteration 594, loss = 0.30943939
# Iteration 595, loss = 0.30930376
# Iteration 596, loss = 0.30931216
# Iteration 597, loss = 0.30907656
# Iteration 598, loss = 0.30914270
# Iteration 599, loss = 0.30898048
# Iteration 600, loss = 0.30918717
# Iteration 601, loss = 0.30902368
# Iteration 602, loss = 0.30878739
# Iteration 603, loss = 0.30867265
# Iteration 604, loss = 0.30877430
# Iteration 605, loss = 0.30869710
# Iteration 606, loss = 0.30872123
# Iteration 607, loss = 0.30846746
# Iteration 608, loss = 0.30843886
# Iteration 609, loss = 0.30839869
# Iteration 610, loss = 0.30856962
# Iteration 611, loss = 0.30844004
# Iteration 612, loss = 0.30814935
# Iteration 613, loss = 0.30818760
# Iteration 614, loss = 0.30808122
# Iteration 615, loss = 0.30804384
# Iteration 616, loss = 0.30792032
# Iteration 617, loss = 0.30762297
# Iteration 618, loss = 0.30775308
# Iteration 619, loss = 0.30748136
# Iteration 620, loss = 0.30781751
# Iteration 621, loss = 0.30748575
# Iteration 622, loss = 0.30749654
# Iteration 623, loss = 0.30759040
# Iteration 624, loss = 0.30737490
# Iteration 625, loss = 0.30731070
# Iteration 626, loss = 0.30726996
# Iteration 627, loss = 0.30705645
# Iteration 628, loss = 0.30689828
# Iteration 629, loss = 0.30694473
# Iteration 630, loss = 0.30703922
# Iteration 631, loss = 0.30685086
# Iteration 632, loss = 0.30694101
# Iteration 633, loss = 0.30652680
# Iteration 634, loss = 0.30653631
# Iteration 635, loss = 0.30658207
# Iteration 636, loss = 0.30686140
# Iteration 637, loss = 0.30657608
# Iteration 638, loss = 0.30653180
# ...
# Iteration 380, loss = 0.33074293
# Iteration 381, loss = 0.33069975
# Iteration 382, loss = 0.33058465
# Iteration 383, loss = 0.33037163
# Iteration 384, loss = 0.33036237
# Iteration 385, loss = 0.33018894
# Iteration 386, loss = 0.33012749
# Iteration 387, loss = 0.33009996
# Iteration 388, loss = 0.32992471
# Iteration 389, loss = 0.32972016
# Iteration 390, loss = 0.32943510
# Iteration 391, loss = 0.32940976
# Iteration 392, loss = 0.32947818
# Iteration 393, loss = 0.32909202
# Iteration 394, loss = 0.32916645
# Iteration 395, loss = 0.32898466
# Iteration 396, loss = 0.32889443
# Iteration 397, loss = 0.32900231
# Iteration 398, loss = 0.32862335
# Iteration 399, loss = 0.32902214
# Iteration 400, loss = 0.32838534
# Iteration 401, loss = 0.32836204
# Iteration 402, loss = 0.32830215
# Iteration 403, loss = 0.32832659
# Iteration 404, loss = 0.32816182
# Iteration 405, loss = 0.32805229
# Iteration 406, loss = 0.32788104
# Iteration 407, loss = 0.32786325
# Iteration 408, loss = 0.32764298
# Iteration 409, loss = 0.32745233
# Iteration 410, loss = 0.32741303
# Iteration 411, loss = 0.32737825
# Iteration 412, loss = 0.32720647
# Iteration 413, loss = 0.32728435
# Iteration 414, loss = 0.32695857
# Iteration 415, loss = 0.32724598
# Iteration 416, loss = 0.32660329
# Iteration 417, loss = 0.32659733
# Iteration 418, loss = 0.32656570
# Iteration 419, loss = 0.32637906
# Iteration 420, loss = 0.32628438
# Iteration 421, loss = 0.32628282
# Iteration 422, loss = 0.32614423
# Iteration 423, loss = 0.32580086
# Iteration 424, loss = 0.32608411
# Iteration 425, loss = 0.32567085
# Iteration 426, loss = 0.32554495
# Iteration 427, loss = 0.32540723
# Iteration 428, loss = 0.32519719
# Iteration 429, loss = 0.32513577
# Iteration 430, loss = 0.32509184
# Iteration 431, loss = 0.32498930
# Iteration 432, loss = 0.32481242
# Iteration 433, loss = 0.32493516
# Iteration 434, loss = 0.32463425
# Iteration 435, loss = 0.32473102
# Iteration 436, loss = 0.32437337
# Iteration 437, loss = 0.32454994
# Iteration 438, loss = 0.32417334
# Iteration 439, loss = 0.32401024
# Iteration 440, loss = 0.32389841
# Iteration 441, loss = 0.32388290
# Iteration 442, loss = 0.32386427
# Iteration 443, loss = 0.32357507
# Iteration 444, loss = 0.32362504
# Iteration 445, loss = 0.32364500
# Iteration 446, loss = 0.32309220
# Iteration 447, loss = 0.32310317
# Iteration 448, loss = 0.32294633
# Iteration 449, loss = 0.32266194
# Iteration 450, loss = 0.32259911
# Iteration 451, loss = 0.32259084
# Iteration 452, loss = 0.32249568
# Iteration 453, loss = 0.32231103
# Iteration 454, loss = 0.32215936
# Iteration 455, loss = 0.32210922
# Iteration 456, loss = 0.32221851
# Iteration 457, loss = 0.32202209
# Iteration 458, loss = 0.32178792
# Iteration 459, loss = 0.32164045
# Iteration 460, loss = 0.32148043
# Iteration 461, loss = 0.32138163
# Iteration 462, loss = 0.32119930
# Iteration 463, loss = 0.32104960
# Iteration 464, loss = 0.32105260
# Iteration 465, loss = 0.32106991
# Iteration 466, loss = 0.32093759
# Iteration 467, loss = 0.32087396
# Iteration 468, loss = 0.32058991
# Iteration 469, loss = 0.32062858
# Iteration 470, loss = 0.32098672
# Iteration 471, loss = 0.32064472
# Iteration 472, loss = 0.32033000
# Iteration 473, loss = 0.32019804
# Iteration 474, loss = 0.32007270
# Iteration 475, loss = 0.32002449
# Iteration 476, loss = 0.31989029
# Iteration 477, loss = 0.32013484
# Iteration 478, loss = 0.31960371
# Iteration 479, loss = 0.31968442
# Iteration 480, loss = 0.31974509
# Iteration 481, loss = 0.31943119
# Iteration 482, loss = 0.31953732
# Iteration 483, loss = 0.31924210
# Iteration 484, loss = 0.31910514
# Iteration 485, loss = 0.31922863
# Iteration 486, loss = 0.31892173
# Iteration 487, loss = 0.31890085
# Iteration 488, loss = 0.31859480
# Iteration 489, loss = 0.31858887
# Iteration 490, loss = 0.31873913
# Iteration 491, loss = 0.31837842
# Iteration 492, loss = 0.31825048
# Iteration 493, loss = 0.31862192
# Iteration 494, loss = 0.31841794
# Iteration 495, loss = 0.31809172
# Iteration 496, loss = 0.31784630
# Iteration 497, loss = 0.31805953
# Iteration 498, loss = 0.31804616
# Iteration 499, loss = 0.31783903
# Iteration 500, loss = 0.31763609
# Iteration 501, loss = 0.31757359
# Iteration 502, loss = 0.31748848
# Iteration 503, loss = 0.31750921
# Iteration 504, loss = 0.31736439
# Iteration 505, loss = 0.31730478
# Iteration 506, loss = 0.31722524
# Iteration 507, loss = 0.31702342
# Iteration 508, loss = 0.31717431
# Iteration 509, loss = 0.31707581
# Iteration 510, loss = 0.31710413
# Iteration 511, loss = 0.31683116
# Iteration 512, loss = 0.31674132
# Iteration 513, loss = 0.31648425
# Iteration 514, loss = 0.31664679
# Iteration 515, loss = 0.31635130
# Iteration 516, loss = 0.31628763
# Iteration 517, loss = 0.31638047
# Iteration 518, loss = 0.31605643
# Iteration 519, loss = 0.31603493
# Iteration 520, loss = 0.31612936
# Iteration 521, loss = 0.31612648
# Iteration 522, loss = 0.31583876
# Iteration 523, loss = 0.31571304
# Iteration 524, loss = 0.31575743
# Iteration 525, loss = 0.31538147
# Iteration 526, loss = 0.31574537
# Iteration 527, loss = 0.31539223
# Iteration 528, loss = 0.31547190
# Iteration 529, loss = 0.31520438
# Iteration 530, loss = 0.31516888
# Iteration 531, loss = 0.31515805
# Iteration 532, loss = 0.31510067
# Iteration 533, loss = 0.31484563
# Iteration 534, loss = 0.31480950
# Iteration 535, loss = 0.31457492
# Iteration 536, loss = 0.31460333
# Iteration 537, loss = 0.31438677
# Iteration 538, loss = 0.31436986
# Iteration 539, loss = 0.31436684
# Iteration 540, loss = 0.31422940
# Iteration 541, loss = 0.31429916
# Iteration 542, loss = 0.31403347
# Iteration 543, loss = 0.31409585
# Iteration 544, loss = 0.31404990
# Iteration 545, loss = 0.31379959
# Iteration 546, loss = 0.31386047
# Iteration 547, loss = 0.31364332
# Iteration 548, loss = 0.31390315
# Iteration 549, loss = 0.31367652
# Iteration 550, loss = 0.31368880
# Iteration 551, loss = 0.31338198
# Iteration 552, loss = 0.31363662
# Iteration 553, loss = 0.31364711
# Iteration 554, loss = 0.31334021
# Iteration 555, loss = 0.31306700
# Iteration 556, loss = 0.31295231
# Iteration 557, loss = 0.31297719
# Iteration 558, loss = 0.31293427
# Iteration 559, loss = 0.31297352
# Iteration 560, loss = 0.31302477
# Iteration 561, loss = 0.31261657
# Iteration 562, loss = 0.31276366
# Iteration 563, loss = 0.31264675
# Iteration 564, loss = 0.31243426
# Iteration 565, loss = 0.31306645
# Iteration 566, loss = 0.31205614
# Iteration 567, loss = 0.31223943
# Iteration 568, loss = 0.31251859
# Iteration 569, loss = 0.31182333
# Iteration 570, loss = 0.31204645
# Iteration 571, loss = 0.31210667
# Iteration 572, loss = 0.31194454
# Iteration 573, loss = 0.31187600
# Iteration 574, loss = 0.31176727
# Iteration 575, loss = 0.31175432
# Iteration 576, loss = 0.31144865
# Iteration 577, loss = 0.31137502
# Iteration 578, loss = 0.31149433
# Iteration 579, loss = 0.31116216
# Iteration 580, loss = 0.31110741
# Iteration 581, loss = 0.31102454
# Iteration 582, loss = 0.31115777
# Iteration 583, loss = 0.31118609
# Iteration 584, loss = 0.31100862
# Iteration 585, loss = 0.31076500
# Iteration 586, loss = 0.31069348
# Iteration 587, loss = 0.31077666
# Iteration 588, loss = 0.31076113
# Iteration 589, loss = 0.31094492
# Iteration 590, loss = 0.31053234
# Iteration 591, loss = 0.31031661
# Iteration 592, loss = 0.31045823
# Iteration 593, loss = 0.31008902
# Iteration 594, loss = 0.31059205
# Iteration 595, loss = 0.31003753
# Iteration 596, loss = 0.30995451
# Iteration 597, loss = 0.31049087
# Iteration 598, loss = 0.31043417
# Iteration 599, loss = 0.30979964
# Iteration 600, loss = 0.30970522
# Iteration 601, loss = 0.30966490
# Iteration 602, loss = 0.30949697
# Iteration 603, loss = 0.30954770
# Iteration 604, loss = 0.30988959
# Iteration 605, loss = 0.30942121
# Iteration 606, loss = 0.30929734
# Iteration 607, loss = 0.30920451
# Iteration 608, loss = 0.30905360
# Iteration 609, loss = 0.30900537
# Iteration 610, loss = 0.30900792
# Iteration 611, loss = 0.30901642
# Iteration 612, loss = 0.30883402
# Iteration 613, loss = 0.30946166
# Iteration 614, loss = 0.30858209
# Iteration 615, loss = 0.30867513
# Iteration 616, loss = 0.30850762
# Iteration 617, loss = 0.30861487
# Iteration 618, loss = 0.30908027
# Iteration 619, loss = 0.30862186
# Iteration 620, loss = 0.30835740
# Iteration 621, loss = 0.30845509
# Iteration 622, loss = 0.30840552
# Iteration 623, loss = 0.30811476
# Iteration 624, loss = 0.30801888
# Iteration 625, loss = 0.30803324
# Iteration 626, loss = 0.30777974
# Iteration 627, loss = 0.30795804
# Iteration 628, loss = 0.30782974
# Iteration 629, loss = 0.30778795
# Iteration 630, loss = 0.30765467
# Iteration 631, loss = 0.30754428
# Iteration 632, loss = 0.30793216
# Iteration 633, loss = 0.30764486
# Iteration 634, loss = 0.30757386
# Iteration 635, loss = 0.30749262
# Iteration 636, loss = 0.30764673
# Iteration 637, loss = 0.30745157
# Iteration 638, loss = 0.30727310
# Iteration 639, loss = 0.30725112
# Iteration 640, loss = 0.30719013
# Iteration 641, loss = 0.30729051
# Iteration 642, loss = 0.30705231
# Iteration 643, loss = 0.30705312
# Iteration 644, loss = 0.30697564
# Iteration 645, loss = 0.30671391
# Iteration 646, loss = 0.30696903
# Iteration 647, loss = 0.30676414
# Iteration 648, loss = 0.30699205
# Iteration 649, loss = 0.30654236
# Iteration 650, loss = 0.30660212
# Iteration 651, loss = 0.30652451
# Iteration 652, loss = 0.30636102
# Iteration 653, loss = 0.30641008
# Iteration 654, loss = 0.30628539
# Iteration 655, loss = 0.30629433
# Iteration 656, loss = 0.30625559
# Iteration 657, loss = 0.30605766
# Iteration 658, loss = 0.30607306
# Iteration 659, loss = 0.30623090
# Iteration 660, loss = 0.30595253
# Iteration 661, loss = 0.30596248
# Iteration 662, loss = 0.30628665
# Iteration 663, loss = 0.30574528
# Iteration 664, loss = 0.30577715
# Iteration 665, loss = 0.30583975
# Iteration 666, loss = 0.30585400
# Iteration 667, loss = 0.30556352
# Iteration 668, loss = 0.30562095
# Iteration 669, loss = 0.30553664
# Iteration 670, loss = 0.30555759
# Iteration 671, loss = 0.30519995
# Iteration 672, loss = 0.30542446
# Iteration 673, loss = 0.30514678
# Iteration 674, loss = 0.30522763
# Iteration 675, loss = 0.30530754
# Iteration 676, loss = 0.30503214
# Iteration 677, loss = 0.30534942
# Iteration 678, loss = 0.30506449
# Iteration 679, loss = 0.30498802
# Iteration 680, loss = 0.30494191
# Iteration 681, loss = 0.30500658
# Iteration 682, loss = 0.30478716
# Iteration 683, loss = 0.30498844
# Iteration 684, loss = 0.30487451
# Iteration 685, loss = 0.30469074
# Iteration 686, loss = 0.30458404
# Iteration 687, loss = 0.30450802
# Iteration 688, loss = 0.30469056
# Iteration 689, loss = 0.30436306
# Iteration 690, loss = 0.30460677
# Iteration 691, loss = 0.30429419
# Iteration 692, loss = 0.30444644
# Iteration 693, loss = 0.30442712
# Iteration 694, loss = 0.30443222
# Iteration 695, loss = 0.30413993
# Iteration 696, loss = 0.30409748
# Iteration 697, loss = 0.30407279
# Iteration 698, loss = 0.30391036
# Iteration 699, loss = 0.30394646
# Iteration 700, loss = 0.30393974
# Iteration 701, loss = 0.30385223
# Iteration 702, loss = 0.30383187
# Iteration 703, loss = 0.30420907
# Iteration 704, loss = 0.30372602
# Iteration 705, loss = 0.30368187
# Iteration 706, loss = 0.30356387
# Iteration 707, loss = 0.30377321
# Iteration 708, loss = 0.30351039
# Iteration 709, loss = 0.30384476
# Iteration 710, loss = 0.30352031
# Iteration 711, loss = 0.30326862
# Iteration 712, loss = 0.30358911
# Iteration 713, loss = 0.30351378
# Iteration 714, loss = 0.30324491
# Iteration 715, loss = 0.30313457
# Iteration 716, loss = 0.30338209
# Iteration 717, loss = 0.30331000
# Iteration 718, loss = 0.30305360
# Iteration 719, loss = 0.30313687
# Iteration 720, loss = 0.30297085
# Iteration 721, loss = 0.30320334
# Iteration 722, loss = 0.30269524
# Iteration 723, loss = 0.30272628
# Iteration 724, loss = 0.30281358
# Iteration 725, loss = 0.30292781
# Iteration 726, loss = 0.30260548
# Iteration 727, loss = 0.30270114
# Iteration 728, loss = 0.30261172
# Iteration 729, loss = 0.30252704
# Iteration 730, loss = 0.30263061
# Iteration 731, loss = 0.30241074
# Iteration 732, loss = 0.30245590
# Iteration 733, loss = 0.30244554
# Iteration 734, loss = 0.30246616
# Iteration 735, loss = 0.30217856
# Iteration 736, loss = 0.30206704
# Iteration 737, loss = 0.30223972
# Iteration 738, loss = 0.30229658
# Iteration 739, loss = 0.30203392
# Iteration 740, loss = 0.30210070
# Iteration 741, loss = 0.30222437
# Iteration 742, loss = 0.30212137
# Iteration 743, loss = 0.30217207
# Iteration 744, loss = 0.30168579
# Iteration 745, loss = 0.30197408
# Iteration 746, loss = 0.30198718
# Iteration 747, loss = 0.30174026
# Iteration 748, loss = 0.30169797
# Iteration 749, loss = 0.30169087
# Iteration 750, loss = 0.30168815
# Iteration 751, loss = 0.30167797
# Iteration 752, loss = 0.30135980
# Iteration 753, loss = 0.30139504
# Iteration 754, loss = 0.30127462
# Iteration 755, loss = 0.30138472
# Iteration 756, loss = 0.30133766
# Iteration 757, loss = 0.30136830
# Iteration 758, loss = 0.30103780
# Iteration 759, loss = 0.30107476
# Iteration 760, loss = 0.30097084
# Iteration 761, loss = 0.30090152
# Iteration 762, loss = 0.30087424
# Iteration 763, loss = 0.30077164
# Iteration 764, loss = 0.30099042
# Iteration 765, loss = 0.30093120
# Iteration 766, loss = 0.30078888
# Iteration 767, loss = 0.30046467
# Iteration 768, loss = 0.30055803
# Iteration 769, loss = 0.30058806
# Iteration 770, loss = 0.30047128
# Iteration 771, loss = 0.30069588
# Iteration 772, loss = 0.30078029
# Iteration 773, loss = 0.30050162
# Iteration 774, loss = 0.30038332
# Iteration 775, loss = 0.30037368
# Iteration 776, loss = 0.30010071
# Iteration 777, loss = 0.30007812
# Iteration 778, loss = 0.30011151
# Iteration 779, loss = 0.30016615
# Iteration 780, loss = 0.30010818
# Iteration 781, loss = 0.30015926
# Iteration 782, loss = 0.30017560
# Iteration 783, loss = 0.30035832
# Iteration 784, loss = 0.29997516
# Iteration 785, loss = 0.29976481
# Iteration 786, loss = 0.29986021
# Iteration 787, loss = 0.30035211
# Iteration 788, loss = 0.30012755
# Iteration 789, loss = 0.29974988
# Iteration 790, loss = 0.29999622
# Iteration 791, loss = 0.30007437
# Iteration 792, loss = 0.29983915
# Iteration 793, loss = 0.29953727
# Iteration 794, loss = 0.29938747
# Iteration 795, loss = 0.29933723
# Iteration 796, loss = 0.29939951
# Iteration 797, loss = 0.29929983
# Iteration 798, loss = 0.29946788
# Iteration 799, loss = 0.29924061
# Iteration 800, loss = 0.29921406
# Iteration 801, loss = 0.29908655
# Iteration 802, loss = 0.29961266
# Iteration 803, loss = 0.29901076
# Iteration 804, loss = 0.29923156
# Iteration 805, loss = 0.29915125
# Iteration 806, loss = 0.29891251
# Iteration 807, loss = 0.29898657
# Iteration 808, loss = 0.29884352
# Iteration 809, loss = 0.29911909
# Iteration 810, loss = 0.29878659
# Iteration 811, loss = 0.29889523
# Iteration 812, loss = 0.29874028
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preproc',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          [6,
#                                                                           7]),
#                                                                         ('num',
#                                                                          StandardScaler(),
#                                                                          [0, 1,
#                                                                           2, 3,
#                                                                           4, 5,
#                                                                           8,
#                                                                           9])])),
#                                        ('classifier',
#                                         MLPClassifier(max_iter=1500,
#                                                       random_state=42,
#                                                       verbose=True))]),
#              param_grid={'classifier__activation': ['relu'],
#                          'classifier__alpha': [0.1],
#                          'classifier__hidden_layer_sizes': [(28,)],
#                          'classifier__solver': ['adam']},
#              scoring=make_scorer(accuracy_score, response_method='predict'))

# %%
print(model_ann.best_params_)
# Print the best cross-validation score
best_score_ann = model_ann.best_score_
print(f"\nBest Cross-Validation Score: {best_score_ann}")
# Out:
# {'classifier__activation': 'relu', 'classifier__alpha': 0.1, 'classifier__hidden_layer_sizes': (28,), 'classifier__solver': 'adam'}
#
# Best Cross-Validation Score: 0.8153335872532217

# %%
# Accessing the best GridSearchCV model
best_model = model_ann.best_estimator_

# Accessing loss history
historico_perda = best_model.named_steps['classifier'].loss_curve_

# Plotting the loss graph
plt.plot(np.arange(1, len(historico_perda) + 1), historico_perda, label='Training sample', color='darkred')
plt.title('Loss Graph Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score

# Make predictions using the model
y_pred_ann = model_ann.predict(X_test)

# Calculate overall accuracy
overall_accuracy = accuracy_score(y_test, y_pred_ann)
print(f"Overall accuracy: {overall_accuracy * 100:.2f}%")

# Calculate accuracy for class 0
accuracy_class_0 = accuracy_score(y_test[y_test == 0], y_pred_ann[y_test == 0])
print(f"Accuracy for class 0: {accuracy_class_0 * 100:.2f}%")

# Calculate accuracy for class 1
accuracy_class_1 = accuracy_score(y_test[y_test == 1], y_pred_ann[y_test == 1])
print(f"Accuracy for class 1: {accuracy_class_1 * 100:.2f}%")
# Out:
# Overall accuracy: 83.40%
# Accuracy for class 0: 72.00%
# Accuracy for class 1: 89.88%

# %%
# Perform predictions on the training dataset using the trained artificial neural network model.
y_pred_ann_train = model_ann.predict(X_train)

# %%
# Calculate evaluation metrics

print("Evaluation metrics for ANN:")
print("Accuracy (Test)/Overall Accuracy:", accuracy_score(y_test, y_pred_ann))
print("Accuracy (Training):", accuracy_score(y_train, y_pred_ann_train))

print("Cohen's Kappa Score:", cohen_kappa_score(y_test, y_pred_ann))

print(classification_report(y_test, y_pred_ann, target_names=['non-landslide', 'landslide']))
# Out:
# Evaluation metrics for ANN:
# Accuracy (Test)/Overall Accuracy: 0.83399209486166
# Accuracy (Training): 0.8915866741953699
# Cohen's Kappa Score: 0.6326685820517154
#                precision    recall  f1-score   support
#
# non-landslide       0.80      0.72      0.76       275
#     landslide       0.85      0.90      0.87       484
#
#      accuracy                           0.83       759
#     macro avg       0.83      0.81      0.82       759
#  weighted avg       0.83      0.83      0.83       759

# %%
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_ann)

# Plot the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds')
plt.title('Confusion Matrix - Total area: Artificial Neural Networks')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks([0.5, 1.5], ['Non-landslide', 'Landslide'])
plt.yticks([0.5, 1.5], ['Non-landslide', 'Landslide'])
plt.show()

# %%
# Calculate metrics
overall_accuracy = accuracy_score(y_test, y_pred_ann)
kappa = cohen_kappa_score(y_test, y_pred_ann)

# Extract values from the confusion matrix
tn, fp, fn, tp = conf_matrix.ravel()

# Calculate Sensitivity and Specificity
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Print results
print(f'Overall Accuracy: {overall_accuracy:.4f}')
print(f'Kappa: {kappa:.4f}')
print(f'Sensitivity ANN: {sensitivity:.4f}')
print(f'Specificity ANN: {specificity:.4f}')
# Out:
# Overall Accuracy: 0.8340
# Kappa: 0.6327
# Sensitivity ANN: 0.8988
# Specificity ANN: 0.7200

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba_ann = model_ann.predict_proba(X_test)[:, 1]

# Calculate false positive rate and true positive rate
fpr_ann, tpr_ann, thresholds = roc_curve(y_test, y_pred_proba_ann)

# Calculate area under the ROC curve
roc_auc_ann = auc(fpr_ann, tpr_ann)

# Plot the ROC curve
plt.figure()
plt.plot(fpr_ann, tpr_ann, color='darkred', lw=1.5, label='ROC Curve (AUC = %0.3f)' % roc_auc_ann)
plt.plot([0, 1], [0, 1], color='navy', lw=1.5, linestyle='--', alpha=0.5)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - ANN - Total area')
plt.legend(loc="lower right")
plt.show()

# %%
# Find indices where the model misclassified class 0
error_indices_class_0 = np.where((y_test == 0) & (y_pred_ann != 0))[0]

# Examine features of misclassified examples in class 0
misclassified_examples_class_0 = X_test.iloc[error_indices_class_0, :]

# Find indices where the model misclassified class 1
error_indices_class_1 = np.where((y_test == 1) & (y_pred_ann != 1))[0]

# Examine features of misclassified examples in class 1
misclassified_examples_class_1 = X_test.iloc[error_indices_class_1, :]

# Calculate the number of errors in class 0
num_errors_class_0 = misclassified_examples_class_0.shape[0]
print("Number of errors in class 0:", num_errors_class_0)

# Calculate the number of errors in class 1
num_errors_class_1 = misclassified_examples_class_1.shape[0]
print("Number of errors in class 1:", num_errors_class_1)
# Out:
# Number of errors in class 0: 77
# Number of errors in class 1: 49

# %%
# Perform predictions on the training dataset using the trained artificial neural network model.
y_pred_ann_train = model_ann.predict(X_train)

# %%
# Combine misclassified indices
error_indices = np.concatenate([error_indices_class_0, error_indices_class_1])

# Extract misclassified examples from the original DataFrame
misclassified_examples = df.iloc[error_indices, :]

# Display the misclassified examples DataFrame
print("Misclassified Examples:")
print(misclassified_examples)
# Out:
# Misclassified Examples:
#           SPI       TWI      Slope  Distance_from_drainages  \
# 2    0.544214  3.610038  21.540659               184.560288
# 5    4.929677  7.543278  28.000000               167.705098
# 8    2.972396  4.403318  48.332184                51.538820
# 10   2.832285  4.733507  37.947330                45.069391
# 26   2.392945  4.535607  32.984844               142.521928
# ..        ...       ...        ...                      ...
# 734  3.597518  4.451652  64.124878                55.901699
# 737  1.447226  4.094195  25.298222               404.853368
# 746  2.643624  3.710778  57.271286               184.560288
# 751  0.730886  3.424152  25.298222                12.500000
# 752  0.600524  4.935915  11.313708               345.732917
#
#      Distance_from_faults  Elevation  Lithology  Aspect  Planform_curvature  \
# 2               17.677670      968.0          3       3           -0.308966
# 5               45.069389      916.0          3       1            0.000000
# 8              166.770798      974.0          3       8           -0.519452
# 10             152.069061      967.0          3       7           -0.736000
# 26             250.000000      931.0          3       7            0.225882
# ..                    ...        ...        ...     ...                 ...
# 734            240.442307      849.0          3       1            0.662412
# 737             55.901699     1012.0          3       7            0.096000
# 746            142.521927      866.0          3       8           -1.289366
# 751             37.500000      944.0          3       1            0.096000
# 752             55.901699      929.0          3       4           -0.159150
#
#      Profile_curvature  Target
# 2             0.331034       1
# 5             0.640000       1
# 8             0.760548       1
# 10            0.544000       1
# 26            0.225882       1
# ..                 ...     ...
# 734          -1.257588       1
# 737           0.096000       1
# 746           0.630634       1
# 751           0.096000       1
# 752          -0.159150       1
#
# [126 rows x 11 columns]

# %%
# List of columns to visualize
columns_to_visualize = misclassified_examples_class_0.columns

# Number of columns desired in the grid
num_columns = len(columns_to_visualize)

# Number of rows needed for the grid
num_rows = (num_columns + 3) // 4  # Round up to ensure at least 1 row

# Create the grid of subplots
fig, axs = plt.subplots(num_rows, 4, figsize=(15, 2 * num_rows), gridspec_kw={'hspace': 0.5, 'wspace': 0.5})

# Add main title to the figure
fig.suptitle('Distribution of Misclassifications by Class', fontsize=16, y=1.0)

# Iterate over columns and plot histograms
for i, column in enumerate(columns_to_visualize):
    row = i // 4
    col = i % 4

    axs[row, col].hist(misclassified_examples_class_0[column], bins=20, color='gray', alpha=0.7, label='Class 0: Non-occurrence')
    axs[row, col].set_xlabel(column)
    axs[row, col].set_ylabel('Frequency')

    # Check if there are data for class 1 before plotting
    if not misclassified_examples_class_1.empty:
        axs[row, col].hist(misclassified_examples_class_1[column], bins=20, color='darkred', alpha=0.7, label='Class 1: Occurrence')

# Remove empty subplots, if any
for i in range(len(columns_to_visualize), num_rows * 4):
    fig.delaxes(axs.flatten()[i])

# Add a single legend for the entire figure
handles, labels = axs[0, 0].get_legend_handles_labels()

# Position of the last subplot in the last row
pos_last_subplot = axs[-1, -2].get_position()

# Legend position
fig.legend(handles, labels, loc='center', fontsize=12, bbox_to_anchor=(pos_last_subplot.x1 + (pos_last_subplot.x1 - pos_last_subplot.x0) / 2, pos_last_subplot.y0 + (pos_last_subplot.y1 - pos_last_subplot.y0) / 2))

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
# Check error distribution for Lithology
error_distribution_lithology_class_0 = misclassified_examples_class_0['Lithology'].value_counts()
error_distribution_lithology_class_1 = misclassified_examples_class_1['Lithology'].value_counts() if misclassified_examples_class_1 is not None else pd.Series()

# Check error distribution for Aspect
error_distribution_aspect_class_0 = misclassified_examples_class_0['Aspect'].value_counts()
error_distribution_aspect_class_1 = misclassified_examples_class_1['Aspect'].value_counts() if misclassified_examples_class_1 is not None else pd.Series()

# Display the results
print("Error distribution by Lithology (Class 0: Non-occurrence):")
print(error_distribution_lithology_class_0)
print("\nError distribution by Lithology (Class 1: Occurrence):")
print(error_distribution_lithology_class_1)

print("\nError distribution by Aspect (Class 0: Non-occurrence):")
print(error_distribution_aspect_class_0)
print("\nError distribution by Aspect (Class 1: Occurrence):")
print(error_distribution_aspect_class_1)
# Out:
# Error distribution by Lithology (Class 0: Non-occurrence):
# Lithology
# 3     67
# 1      4
# 6      2
# 7      2
# 15     1
# 17     1
# Name: count, dtype: int64
#
# Error distribution by Lithology (Class 1: Occurrence):
# Lithology
# 3    42
# 1     3
# 7     2
# 9     1
# 6     1
# Name: count, dtype: int64
#
# Error distribution by Aspect (Class 0: Non-occurrence):
# Aspect
# 7    16
# 8    14
# 1    13
# 6    10
# 4     9
# 2     7
# 3     5
# 5     3
# Name: count, dtype: int64
#
# Error distribution by Aspect (Class 1: Occurrence):
# Aspect
# 2    12
# 7     9
# 5     7
# 3     6
# 8     5
# 1     5
# 6     3
# 4     2
# Name: count, dtype: int64

# %%
from sklearn.inspection import permutation_importance

# %%
# Calculate permutation importance using X
result_ann = permutation_importance(best_model, X, y, n_repeats=300, random_state=42)

# Extract feature importances
importances_ann = result_ann.importances_mean

# Create a DataFrame to visualize the importances
importance_df_ann = pd.DataFrame({'Feature': X.columns, 'Importance': importances_ann})
importance_df_ann = importance_df_ann.sort_values(by='Importance', ascending=False)

# Convert importances to percentage
importance_df_ann['Importance'] *= 100

# Plot a bar chart to show the ordered feature importances
plt.bar(range(len(importance_df_ann)), importance_df_ann['Importance'], tick_label=importance_df_ann['Feature'], color='darkred', alpha=0.7)
plt.title('Feature Importance in ANN Model')
plt.xlabel('Features')
plt.ylabel('Importance (%)')
plt.xticks(rotation=45, ha='right')  # Rotate labels for better readability
plt.grid(False)
plt.tight_layout()  # Adjust layout to ensure labels do not overlap
plt.show()

# %%
# List the variables and their importance
for feature, importance in zip(importance_df_ann['Feature'], importance_df_ann['Importance']):
    print(f'{feature}: {importance:.2f}%')
# Out:
# Slope: 16.15%
# Elevation: 11.16%
# Aspect: 8.28%
# Distance_from_faults: 6.82%
# Lithology: 5.62%
# Distance_from_drainages: 5.26%
# Planform_curvature: 4.24%
# Profile_curvature: 3.71%
# SPI: 3.62%
# TWI: 3.10%

# %%
import xgboost as xgb

# Create a DMatrix object for training and test data
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Specify model parameters
params_xgb = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'random_state': 42
}

# Train the model
num_boost_round = 100
xgb_model = xgb.train(params_xgb, dtrain, num_boost_round=num_boost_round)

# Make predictions on the test set
y_pred_prob_xgb = xgb_model.predict(dtest)
y_pred_class_xgb = [1 if pred > 0.5 else 0 for pred in y_pred_prob_xgb]

# Calculate accuracy
accuracy_xgb = accuracy_score(y_test, y_pred_class_xgb)
print(f'XGBoost model accuracy: {accuracy_xgb:.4f}')

# Calculate feature importance
importance_xgb = xgb_model.get_score(importance_type='weight')

# Normalize feature importance to obtain the percentage
total_importance_xgb = sum(importance_xgb.values())
feature_importance_percentage = {feature: (count / total_importance_xgb) * 100 for feature, count in importance_xgb.items()}

# Sort features by importance in descending order
sorted_feature_importance = sorted(feature_importance_percentage.items(), key=lambda x: x[1], reverse=True)

# Display feature importance in percentage
for feature, importance_percentage in sorted_feature_importance:
    print(f'{feature}: {importance_percentage:.2f}%')
# Out:
# XGBoost model accuracy: 0.8248
# Elevation: 15.09%
# Distance_from_faults: 13.55%
# Distance_from_drainages: 12.48%
# SPI: 11.76%
# TWI: 11.42%
# Profile_curvature: 9.24%
# Slope: 8.85%
# Planform_curvature: 8.51%
# Aspect: 6.24%
# Lithology: 2.85%

# %%
import joblib
from google.colab import files

# Save the best model using joblib
joblib_file = 'model_train_ann_qf.pkl'
joblib.dump(best_model, joblib_file)

# Download the .pkl file
files.download(joblib_file)

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.1)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 23.1 MB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.46.0 slicer-0.0.8

# %%
import shap

# Load the saved model
best_model = joblib.load('model_train_ann_qf.pkl')

# Define the variable names as provided
feature_names = ['SPI', 'TWI', 'Slope', 'Distance_from_drainages', 'Distance_from_faults', 'Elevation', 'Lithology', 'Aspect', 'Planform_curvature', 'Profile_curvature']

# Use a sample of the data for SHAP calculation (to reduce computation time)
X_sample = shap.utils.sample(X, 100)

# Create a wrapper function for prediction
def model_predict(data):
    return best_model.predict(data)

# Create a SHAP explainer using KernelExplainer with the wrapper function
explainer = shap.KernelExplainer(model_predict, X_sample)

# Calculate SHAP values for the sample
shap_values = explainer.shap_values(X_sample)

# Visualize feature importance
shap.summary_plot(shap_values, X_sample, feature_names=feature_names, cmap='autumn_r')

# For a more detailed visualization, you can use the dependence plot
shap.dependence_plot(0, shap_values, X_sample, feature_names=feature_names, cmap=plt.get_cmap('autumn_r'))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Calculate the mean absolute SHAP value for each variable
mean_abs_shap = np.mean(np.abs(shap_values), axis=0)

# Display the feature importance in numbers
for i, name in enumerate(feature_names):
    print(f'Variable {name}: Mean SHAP Importance = {mean_abs_shap[i]}')
# Out:
# Variable SPI: Mean SHAP Importance = 0.03655476190476181
# Variable TWI: Mean SHAP Importance = 0.049434841269841136
# Variable Slope: Mean SHAP Importance = 0.1819310317460313
# Variable Distance_from_drainages: Mean SHAP Importance = 0.03799253968253961
# Variable Distance_from_faults: Mean SHAP Importance = 0.08347730158730139
# Variable Elevation: Mean SHAP Importance = 0.12871301587301553
# Variable Lithology: Mean SHAP Importance = 0.05321976190476181
# Variable Aspect: Mean SHAP Importance = 0.07172587301587283
# Variable Planform_curvature: Mean SHAP Importance = 0.02297531746031734
# Variable Profile_curvature: Mean SHAP Importance = 0.033081269841269884

# %%
# Calculate the sum of absolute SHAP values for each variable
total_abs_shap = np.sum(np.abs(shap_values), axis=0)

# Display the feature importance in numbers
for i, name in enumerate(feature_names):
    print(f'Variable {name}: Sum of absolute SHAP values = {total_abs_shap[i]}')
# Out:
# Variable SPI: Sum of absolute SHAP values = 3.655476190476181
# Variable TWI: Sum of absolute SHAP values = 4.943484126984114
# Variable Slope: Sum of absolute SHAP values = 18.19310317460313
# Variable Distance_from_drainages: Sum of absolute SHAP values = 3.799253968253961
# Variable Distance_from_faults: Sum of absolute SHAP values = 8.347730158730139
# Variable Elevation: Sum of absolute SHAP values = 12.871301587301554
# Variable Lithology: Sum of absolute SHAP values = 5.321976190476181
# Variable Aspect: Sum of absolute SHAP values = 7.172587301587283
# Variable Planform_curvature: Sum of absolute SHAP values = 2.297531746031734
# Variable Profile_curvature: Sum of absolute SHAP values = 3.3081269841269885

# %%
# Calculate the standard deviation of SHAP values for each variable
std_shap = np.std(shap_values, axis=0)

# Calculate percentiles of SHAP values for each variable
percentile_10 = np.percentile(shap_values, 10, axis=0)
percentile_90 = np.percentile(shap_values, 90, axis=0)

# Display the statistics for each variable
for i, name in enumerate(feature_names):
    print(f'Variable {name}: SHAP Standard Deviation = {std_shap[i]}, 10th Percentile = {percentile_10[i]}, 90th Percentile = {percentile_90[i]}')
# Out:
# Variable SPI: SHAP Standard Deviation = 0.06961271316606704, 10th Percentile = -0.040202380952380885, 90th Percentile = 0.04404404761904758
# Variable TWI: SHAP Standard Deviation = 0.09000482089702994, 10th Percentile = -0.05406031746031731, 90th Percentile = 0.050799206349206344
# Variable Slope: SHAP Standard Deviation = 0.21879362789068585, 10th Percentile = -0.3308134920634913, 90th Percentile = 0.23557063492063418
# Variable Distance_from_drainages: SHAP Standard Deviation = 0.05373807270091622, 10th Percentile = -0.0668107142857141, 90th Percentile = 0.06207261904761875
# Variable Distance_from_faults: SHAP Standard Deviation = 0.12671869136892308, 10th Percentile = -0.1441492063492062, 90th Percentile = 0.09930396825396798
# Variable Elevation: SHAP Standard Deviation = 0.19424939959140777, 10th Percentile = -0.25600992063492006, 90th Percentile = 0.13617380952380928
# Variable Lithology: SHAP Standard Deviation = 0.09523142615207911, 10th Percentile = -0.08040317460317437, 90th Percentile = 0.054373412698412595
# Variable Aspect: SHAP Standard Deviation = 0.09232194044833326, 10th Percentile = -0.10050238095238069, 90th Percentile = 0.10939761904761887
# Variable Planform_curvature: SHAP Standard Deviation = 0.03978223791011264, 10th Percentile = -0.03225674603174575, 90th Percentile = 0.027194047619047174
# Variable Profile_curvature: SHAP Standard Deviation = 0.04811989971926581, 10th Percentile = -0.036788095238095155, 90th Percentile = 0.05311706349206376

# %% [markdown]
# Random Forest model

# %%
'''
# Define the hyperparameter grid for grid search
grid_rf = {'classifier__n_estimators': [1, 2, 5, 10, 18, 20 30, 40, 50, 60, 70, 80, 90, 100, 150, 200, 250, 300, 400, 500, 1000, 1200, 1400],
           'classifier__max_features': ['auto', 'sqrt', 'log2', 3, 4, 5],
           'classifier__bootstrap': [True, False],
           'classifier__criterion': ['gini', 'entropy'],
            'classifier__max_depth': [None, 5, 10, 12, 13, 18, 20]
}
print(grid_rf)
'''
# Out:
# "\n# Define the hyperparameter grid for grid search\ngrid_rf = {'classifier__n_estimators': [1, 2, 5, 10, 18, 20 30, 40, 50, 60, 70, 80, 90, 100, 150, 200, 250, 300, 400, 500, 1000, 1200, 1400],\n           'classifier__max_features': ['auto', 'sqrt', 'log2', 3, 4, 5],\n           'classifier__bootstrap': [True, False],\n           'classifier__criterion': ['gini', 'entropy'],\n            'classifier__max_depth': [None, 5, 10, 12, 13, 18, 20]\n}\nprint(grid_rf)\n"

# %%
# Grid search parameters defined for the model
grid_rf = {'classifier__n_estimators': [400],
           'classifier__max_features': [4],
           'classifier__bootstrap': [True],
           'classifier__criterion': ['gini'],
           'classifier__max_depth': [13]

}
print(grid_rf)
# Out:
# {'classifier__n_estimators': [400], 'classifier__max_features': [4], 'classifier__bootstrap': [True], 'classifier__criterion': ['gini'], 'classifier__max_depth': [13]}

# %%
# Create a base classifier
rf = RandomForestClassifier(random_state=42)

# %% [markdown]
#  "Pipeline" is for making workflow with standardization and classification in a few lines of code

# %%
rf_flow = Pipeline([
    ('preproc', preprocessor),
    ('classifier', rf)
])

# %%
# Instantiate the grid search model with 10-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
model_rf = GridSearchCV(rf_flow, param_grid = grid_rf, cv = kfold, scoring=acc_scorer)

# %%
model_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preproc',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          [6,
#                                                                           7]),
#                                                                         ('num',
#                                                                          StandardScaler(),
#                                                                          [0, 1,
#                                                                           2, 3,
#                                                                           4, 5,
#                                                                           8,
#                                                                           9])])),
#                                        ('classifier',
#                                         RandomForestClassifier(random_state=42))]),
#              param_grid={'classifier__bootstrap': [True],
#                          'classifier__criterion': ['gini'],
#                          'classifier__max_depth': [13],
#                          'classifier__max_features': [4],
#                          'classifier__n_estimators': [400]},
#              scoring=make_scorer(accuracy_score, response_method='predict'))

# %% [markdown]
# Best search parameters

# %%
model_rf.best_params_
# Out:
# {'classifier__bootstrap': True,
#  'classifier__criterion': 'gini',
#  'classifier__max_depth': 13,
#  'classifier__max_features': 4,
#  'classifier__n_estimators': 400}

# %%
# Print the best hyperparameters found from all searches
print("Best Hyperparameters Found:")
print(f"- Number of estimators (n_estimators): {model_rf.best_params_['classifier__n_estimators']}")
print(f"- Maximum features (max_features): {model_rf.best_params_['classifier__max_features']}")
print(f"- Bootstrap: {model_rf.best_params_['classifier__bootstrap']}")
print(f"- Criterion: {model_rf.best_params_['classifier__criterion']}")
print(f"- Maximum Depth (max_depth): {model_rf.best_params_['classifier__max_depth']}")

# Print the best cross-validation value
best_score_rf = model_rf.best_score_
print(f"\nBest Cross Validation Value: {best_score_rf}")
# Out:
# Best Hyperparameters Found:
# - Number of estimators (n_estimators): 400
# - Maximum features (max_features): 4
# - Bootstrap: True
# - Criterion: gini
# - Maximum Depth (max_depth): 13
#
# Best Cross Validation Value: 0.8209928267631561

# %%
X.columns
# Out:
# Index(['SPI', 'TWI', 'Slope', 'Distance_from_drainages',
#        'Distance_from_faults', 'Elevation', 'Lithology', 'Aspect',
#        'Planform_curvature', 'Profile_curvature'],
#       dtype='object')

# %%
from sklearn.metrics import accuracy_score

# Make predictions using the model
y_pred_rf = model_rf.predict(X_test)

# Calculate overall accuracy
overall_accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Overall accuracy: {overall_accuracy_rf * 100:.2f}%")

# Calculate accuracy for class 0
accuracy_class_0_rf = accuracy_score(y_test[y_test == 0], y_pred_rf[y_test == 0])
print(f"Accuracy for class 0: {accuracy_class_0_rf * 100:.2f}%")

# Calculate accuracy for class 1
accuracy_class_1_rf = accuracy_score(y_test[y_test == 1], y_pred_rf[y_test == 1])
print(f"Accuracy for class 1: {accuracy_class_1_rf * 100:.2f}%")
# Out:
# Overall accuracy: 83.27%
# Accuracy for class 0: 68.73%
# Accuracy for class 1: 91.53%

# %%
# Perform predictions on the training dataset using the trained RF model.
y_pred_rf_train = model_rf.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_rf)

# Plot the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix - Total area: Random Forest')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.xticks([0.5, 1.5], ['Non-landslide', 'Landslide'])
plt.yticks([0.5, 1.5], ['Non-landslide', 'Landslide'])
plt.show()

# %%
# Calculate evaluation metrics

print("Evaluation metrics for RF:")
print("Accuracy (Test)/Overall Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Accuracy (Training):", accuracy_score(y_train, y_pred_rf_train))

print("Cohen's Kappa Score:", cohen_kappa_score(y_test, y_pred_rf))

print(classification_report(y_test, y_pred_rf, target_names=['non-landslide', 'landslide']))
# Out:
# Evaluation metrics for RF:
# Accuracy (Test)/Overall Accuracy: 0.8326745718050066
# Accuracy (Training): 0.9536984754376059
# Cohen's Kappa Score: 0.6246305418719211
#                precision    recall  f1-score   support
#
# non-landslide       0.82      0.69      0.75       275
#     landslide       0.84      0.92      0.87       484
#
#      accuracy                           0.83       759
#     macro avg       0.83      0.80      0.81       759
#  weighted avg       0.83      0.83      0.83       759

# %%
# Calculate metrics
overall_accuracy = accuracy_score(y_test, y_pred_rf)
kappa = cohen_kappa_score(y_test, y_pred_rf)

# Extract values from the confusion matrix
tn, fp, fn, tp = conf_matrix.ravel()

# Calculate Sensitivity and Specificity
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Print results
print(f'Overall Accuracy: {overall_accuracy:.4f}')
print(f'Kappa: {kappa:.4f}')
print(f'Sensitivity RF: {sensitivity:.4f}')
print(f'Specificity RF: {specificity:.4f}')
# Out:
# Overall Accuracy: 0.8327
# Kappa: 0.6246
# Sensitivity RF: 0.9153
# Specificity RF: 0.6873

# %%
from sklearn.metrics import roc_curve, auc

# Get predicted probabilities for the positive class
y_pred_proba_rf = model_rf.predict_proba(X_test)[:, 1]

# Calculate false positive rate and true positive rate
fpr_rf, tpr_rf, thresholds = roc_curve(y_test, y_pred_proba_rf)

# Calculate area under the ROC curve
roc_auc_rf = auc(fpr_rf, tpr_rf)

# Plot the ROC curve
plt.figure()
plt.plot(fpr_rf, tpr_rf, color='darkgreen', lw=1.5, label='ROC Curve (AUC = %0.3f)' % roc_auc_rf)
plt.plot([0, 1], [0, 1], color='navy', lw=1.5, linestyle='--', alpha=0.5)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - RF - Total area')
plt.legend(loc="lower right")
plt.show()

# %%
# Find indices where the model misclassified class 0
error_indices_class_0_rf = np.where((y_test == 0) & (y_pred_rf != 0))[0]

# Examine features of misclassified examples in class 0
misclassified_examples_class_0_rf = X_test.iloc[error_indices_class_0_rf, :]

# Find indices where the model misclassified class 1
error_indices_class_1_rf = np.where((y_test == 1) & (y_pred_rf != 1))[0]

# Examine features of misclassified examples in class 1
misclassified_examples_class_1_rf = X_test.iloc[error_indices_class_1_rf, :]

# Calculate the number of errors in class 0
num_errors_class_0_rf = misclassified_examples_class_0_rf.shape[0]
print("Number of errors in class 0:", num_errors_class_0_rf)

# Calculate the number of errors in class 1
num_errors_class_1_rf = misclassified_examples_class_1_rf.shape[0]
print("Number of errors in class 1:", num_errors_class_1_rf)
# Out:
# Number of errors in class 0: 86
# Number of errors in class 1: 41

# %%
# Combine misclassified indices
error_indices_rf = np.concatenate([error_indices_class_0_rf, error_indices_class_1_rf])

# Extract misclassified examples from the original DataFrame
misclassified_examples_rf = df.iloc[error_indices_rf, :]

# Display the misclassified examples DataFrame
print("Misclassified Examples RF:")
print(misclassified_examples_rf)
# Out:
# Misclassified Examples RF:
#           SPI       TWI      Slope  Distance_from_drainages  \
# 2    0.544214  3.610038  21.540659               184.560288
# 8    2.972396  4.403318  48.332184                51.538820
# 10   2.832285  4.733507  37.947330                45.069391
# 16   1.515936  3.451246  37.947330               128.695377
# 26   2.392945  4.535607  32.984844               142.521928
# ..        ...       ...        ...                      ...
# 636  2.964582  4.200601  52.153618                12.500000
# 681  2.691329  4.683722  36.878178                50.000000
# 711  2.737377  4.192025  48.166378               475.164445
# 734  3.597518  4.451652  64.124878                55.901699
# 746  2.643624  3.710778  57.271286               184.560288
#
#      Distance_from_faults  Elevation  Lithology  Aspect  Planform_curvature  \
# 2               17.677670      968.0          3       3           -0.308966
# 8              166.770798      974.0          3       8           -0.519452
# 10             152.069061      967.0          3       7           -0.736000
# 16              55.901699      972.0          3       3            0.640000
# 26             250.000000      931.0          3       7            0.225882
# ..                    ...        ...        ...     ...                 ...
# 636             62.500000      944.0          3       8            0.350118
# 681            106.800049     1105.0          3       1           -0.165647
# 711            111.803398      990.0          3       8           -1.156414
# 734            240.442307      849.0          3       1            0.662412
# 746            142.521927      866.0          3       8           -1.289366
#
#      Profile_curvature  Target
# 2             0.331034       1
# 8             0.760548       1
# 10            0.544000       1
# 16           -0.640000       1
# 26            0.225882       1
# ..                 ...     ...
# 636          -0.929882       1
# 681           0.474353       1
# 711           0.763586       1
# 734          -1.257588       1
# 746           0.630634       1
#
# [127 rows x 11 columns]

# %%
# List of columns to visualize
columns_to_visualize_rf = misclassified_examples_class_0_rf.columns

# Number of columns desired in the grid
num_columns_rf = len(columns_to_visualize_rf)

# Number of rows needed for the grid
num_rows_rf = (num_columns_rf + 3) // 4  # Round up to ensure at least 1 row

# Create the grid of subplots
fig, axs = plt.subplots(num_rows_rf, 4, figsize=(15, 2 * num_rows), gridspec_kw={'hspace': 0.5, 'wspace': 0.5})

# Add main title to the figure
fig.suptitle('Distribution of Misclassifications by Class', fontsize=16, y=1.0)

# Iterate over columns and plot histograms
for i, column in enumerate(columns_to_visualize_rf):
    row = i // 4
    col = i % 4

    axs[row, col].hist(misclassified_examples_class_0_rf[column], bins=20, color='gray', alpha=0.7, label='Class 0: Non-occurrence')
    axs[row, col].set_xlabel(column)
    axs[row, col].set_ylabel('Frequency')

    # Check if there are data for class 1 before plotting
    if not misclassified_examples_class_1_rf.empty:
        axs[row, col].hist(misclassified_examples_class_1_rf[column], bins=20, color='darkgreen', alpha=0.7, label='Class 1: Occurrence')

# Remove empty subplots, if any
for i in range(len(columns_to_visualize_rf), num_rows_rf * 4):
    fig.delaxes(axs.flatten()[i])

# Add a single legend for the entire figure
handles, labels = axs[0, 0].get_legend_handles_labels()

# Position of the last subplot in the last row
pos_last_subplot = axs[-1, -2].get_position()

# Legend position
fig.legend(handles, labels, loc='center', fontsize=12, bbox_to_anchor=(pos_last_subplot.x1 + (pos_last_subplot.x1 - pos_last_subplot.x0) / 2, pos_last_subplot.y0 + (pos_last_subplot.y1 - pos_last_subplot.y0) / 2))

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plots
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# Train the RandomForest model
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Access feature importances and feature names
feature_importances = rf.feature_importances_
feature_names = X.columns

# Create a list of tuples (importance, feature name) and sort by importance
sorted_features = sorted(zip(feature_importances, feature_names), reverse=True)

# Unpack the sorted tuples
sorted_importances, sorted_feature_names = zip(*sorted_features)

# Convert importances to percentage
sorted_importances_percentage = [imp * 100 for imp in sorted_importances]

# Plot a bar chart to show the ordered feature importances
plt.bar(range(len(sorted_importances_percentage)), sorted_importances_percentage, tick_label=sorted_feature_names, color='green', alpha=0.7)
plt.title('Feature Importance in RandomForest Model')
plt.xlabel('Features')
plt.ylabel('Importance (%)')
plt.xticks(rotation=45, ha='right')  # Rotate labels for better readability
plt.tight_layout()  # Adjust layout to ensure labels do not overlap
plt.show()

# %%
best_model_rf= model_rf.best_estimator_

# %%
import joblib
from google.colab import files

# Salve o melhor modelo usando joblib
joblib_file_rf = 'model_train_rf_qf.pkl'
joblib.dump(best_model_rf, joblib_file_rf)

# Faça o download do arquivo .pkl
files.download(joblib_file_rf)

# %%
# Load the saved model
best_model_rf_shap = joblib.load('model_train_rf_qf.pkl')

# Define the variable names as provided
feature_names = ['SPI', 'TWI', 'Slope', 'Distance_from_drainages', 'Distance_from_faults', 'Elevation', 'Lithology', 'Aspect', 'Planform_curvature', 'Profile_curvature']

# Use a sample of the data for SHAP calculation (to reduce computation time)
X_sample = shap.utils.sample(X, 100)

# Create a wrapper function for prediction
def model_predict(data):
    return best_model_rf_shap.predict(data)

# Create a SHAP explainer using KernelExplainer with the wrapper function
explainer_rf_shap = shap.KernelExplainer(model_predict, X_sample)

# Calculate SHAP values for the sample
shap_values_rf_shap = explainer_rf_shap.shap_values(X_sample)

# Visualize feature importance
shap.summary_plot(shap_values_rf_shap, X_sample, feature_names=feature_names, cmap='summer_r')

# For a more detailed visualization, you can use the dependence plot
shap.dependence_plot(0, shap_values_rf_shap, X_sample, feature_names=feature_names, cmap='summer_r')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# Calculate the mean absolute SHAP value for each variable
mean_abs_shap_rf = np.mean(np.abs(shap_values_rf_shap), axis=0)

# Display the feature importance in numbers
for i, name in enumerate(feature_names):
    print(f'Variable {name}: Mean SHAP Importance RF = {mean_abs_shap_rf[i]}')
# Out:
# Variable SPI: Mean SHAP Importance RF = 0.05025706349206339
# Variable TWI: Mean SHAP Importance RF = 0.02969261904761896
# Variable Slope: Mean SHAP Importance RF = 0.09224984126984108
# Variable Distance_from_drainages: Mean SHAP Importance RF = 0.011910158730158715
# Variable Distance_from_faults: Mean SHAP Importance RF = 0.09284182539682523
# Variable Elevation: Mean SHAP Importance RF = 0.1305734126984123
# Variable Lithology: Mean SHAP Importance RF = 0.04695611111111102
# Variable Aspect: Mean SHAP Importance RF = 0.022617142857142832
# Variable Planform_curvature: Mean SHAP Importance RF = 0.012741825396825479
# Variable Profile_curvature: Mean SHAP Importance RF = 0.010208888888888996

# %%
# Calculate the sum of absolute SHAP values for each variable
total_abs_shap_rf = np.sum(np.abs(shap_values_rf_shap), axis=0)

# Display the feature importance in numbers
for i, name in enumerate(feature_names):
    print(f'Variable {name}: Sum of absolute SHAP values = {total_abs_shap_rf[i]}')
# Out:
# Variable SPI: Sum of absolute SHAP values = 5.025706349206339
# Variable TWI: Sum of absolute SHAP values = 2.969261904761896
# Variable Slope: Sum of absolute SHAP values = 9.224984126984108
# Variable Distance_from_drainages: Sum of absolute SHAP values = 1.1910158730158715
# Variable Distance_from_faults: Sum of absolute SHAP values = 9.284182539682522
# Variable Elevation: Sum of absolute SHAP values = 13.057341269841231
# Variable Lithology: Sum of absolute SHAP values = 4.695611111111102
# Variable Aspect: Sum of absolute SHAP values = 2.2617142857142833
# Variable Planform_curvature: Sum of absolute SHAP values = 1.274182539682548
# Variable Profile_curvature: Sum of absolute SHAP values = 1.0208888888888996

# %%
# Calculate the standard deviation of SHAP values for each variable
std_shap_rf = np.std(shap_values_rf_shap, axis=0)

# Calculate percentiles of SHAP values for each variable
percentile_10_rf = np.percentile(shap_values_rf_shap, 10, axis=0)
percentile_90_rf = np.percentile(shap_values_rf_shap, 90, axis=0)

# Display the statistics for each variable
for i, name in enumerate(feature_names):
    print(f'Variable {name}: SHAP Standard Deviation = {std_shap_rf[i]}, 10th Percentile = {percentile_10_rf[i]}, 90th Percentile = {percentile_90_rf[i]}')
# Out:
# Variable SPI: SHAP Standard Deviation = 0.07389289153821921, 10th Percentile = -0.08321666666666636, 90th Percentile = 0.05125436507936497
# Variable TWI: SHAP Standard Deviation = 0.04980662891384683, 10th Percentile = -0.06054960317460303, 90th Percentile = 0.03281269841269839
# Variable Slope: SHAP Standard Deviation = 0.12763497342734423, 10th Percentile = -0.18922817460317412, 90th Percentile = 0.09092579365079353
# Variable Distance_from_drainages: SHAP Standard Deviation = 0.023220575948763377, 10th Percentile = -0.012952380952381024, 90th Percentile = 0.01650476190476192
# Variable Distance_from_faults: SHAP Standard Deviation = 0.14108853640377816, 10th Percentile = -0.18768174603174553, 90th Percentile = 0.08970277777777773
# Variable Elevation: SHAP Standard Deviation = 0.21522359466843483, 10th Percentile = -0.19094722222222152, 90th Percentile = 0.10920992063492056
# Variable Lithology: SHAP Standard Deviation = 0.09421480365842205, 10th Percentile = -0.017638888888888902, 90th Percentile = 0.04035833333333337
# Variable Aspect: SHAP Standard Deviation = 0.039028846246298474, 10th Percentile = -0.03483452380952397, 90th Percentile = 0.027226984126984072
# Variable Planform_curvature: SHAP Standard Deviation = 0.03401901569358515, 10th Percentile = -0.014037301587302193, 90th Percentile = 0.00969563492063514
# Variable Profile_curvature: SHAP Standard Deviation = 0.023636088302783867, 10th Percentile = -0.011111507936507836, 90th Percentile = 0.009541666666666861

# %% [markdown]
# Comparison between models

# %%
from sklearn.metrics import recall_score, f1_score, accuracy_score, roc_auc_score

y_probas = [y_pred_proba_ann, y_pred_proba_rf]
model_names = ['ANN', 'Random Forest']

# Create lists to store the metrics
recall_scores = []
f1_scores = []
accuracy_scores = []
roc_auc_scores = []

# Loop through the probability prediction results
for y_proba in y_probas:
    # Convert probabilities to binary labels (using a threshold, e.g., 0.5)
    y_pred = (y_proba > 0.5).astype(int)

    # Calculate the metrics
    recall = recall_score(y_test, y_pred)  # Replace y_test with your actual labels
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_proba)  # Calculate ROC AUC using probabilities

    # Store the metrics in the lists
    recall_scores.append(recall)
    f1_scores.append(f1)
    accuracy_scores.append(accuracy)
    roc_auc_scores.append(roc_auc)

# Create a DataFrame with the metrics
metrics_df = pd.DataFrame({
    'Model': model_names,
    'Recall': recall_scores,
    'F1 Score': f1_scores,
    'Accuracy': accuracy_scores,
    'ROC AUC': roc_auc_scores
})

# Display the table
print(metrics_df)
# Out:
#            Model    Recall  F1 Score  Accuracy   ROC AUC
# 0            ANN  0.898760  0.873494  0.833992  0.878941
# 1  Random Forest  0.915289  0.874630  0.832675  0.914711

# %%
# Map colors to each model
model_colors = {'ANN': 'red', 'Random Forest': 'green'}

# Add a color column to the DataFrame
metrics_df['Color'] = metrics_df['Model'].map(model_colors)

# Melt the DataFrame for easier use with seaborn
metrics_df_melted = pd.melt(metrics_df, id_vars=['Model', 'Color'], var_name='Metric', value_name='Performance')

# Create a grouped bar chart with specific colors for each model
plt.figure(figsize=(9, 6))
ax = sns.barplot(x='Metric', y='Performance', hue='Model', data=metrics_df_melted, palette=list(metrics_df_melted['Color']))

# Add transparency to the bars
for bar in ax.patches:
    bar.set_alpha(0.7)

# Add titles and axis labels
plt.title('Performance Metrics for Different Models')
plt.xlabel('Metrics')
plt.ylabel('Performance')

# Set the y-axis to range from 0 to 1
ax.set_ylim(0, 1)

# Display the chart
plt.legend(title='Model', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Create a line plot with specific colors for each model
plt.figure(figsize=(9, 6))
ax = sns.lineplot(x='Metric', y='Performance', hue='Model', data=metrics_df_melted, palette=model_colors, marker='o', alpha=0.8)

# Add titles and axis labels
plt.title('Performance Metrics for Different Models - QF')
plt.xlabel('Metrics')
plt.ylabel('Performance')

ax.set_ylim(0.8, 1)

# Display the chart
plt.legend(title='Model', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Create a line plot with specific colors for each model
plt.figure(figsize=(9, 6))
ax = sns.lineplot(x='Metric', y='Performance', hue='Model', data=metrics_df_melted, palette=model_colors, marker='o', alpha=0.8)

# Add titles and axis labels
plt.title('Performance Metrics for Different Models - QF')
plt.xlabel('Metrics')
plt.ylabel('Performance')

# Set the y-axis to range from 0.80 to 1
ax.set_ylim(0.80, 1)

# Add horizontal dashed grid lines in light gray
ax.grid(True, which='both', linestyle='--', linewidth=0.5, color='lightgray', axis='y')

# Display the chart
plt.legend(title='Model', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ## Plotting ROC curves for the 2 models

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

# %%
pred_prob_ann=model_ann.predict_proba(X_test)[:,1]
fpr_ann, tpr_ann, threshold1 = roc_curve(y_test, pred_prob_ann, pos_label=1)
# AUC score that summarizes the ROC curve
roc_auc_ann = auc(fpr_ann, tpr_ann)

# %%
pred_prob_rf=model_rf.predict_proba(X_test)[:,1]
fpr_rf, tpr_rf, threshold1 = roc_curve(y_test, pred_prob_rf, pos_label=1)
# AUC score that summarizes the ROC curve
roc_auc_rf = auc(fpr_rf, tpr_rf)

# %%
# AUC score that summarizes the ROC curve
f, ax = plt.subplots(figsize=(10,7))
plt.plot(fpr_ann,tpr_ann, color ='darkred', alpha=0.7, lw=2, label= 'ANN AUC: {:.2f}'.format(roc_auc_ann))
plt.plot(fpr_rf,tpr_rf, color ='darkgreen',alpha=0.7, lw=2, label='RF AUC: {:.2f}'.format(roc_auc_rf))
plt.plot([0, 1], [0, 1],
         linestyle = '--',
         color = (0.6, 0.6, 0.6),
         label = 'random prediction')
plt.plot([0, 0, 1], [0, 1, 1],
         linestyle = ':',
         color = 'black',
         label = 'perfect performance')
plt.xlim([-.05, 1.0])
plt.ylim([-.05, 1.05])
plt.xlabel('False Positive Rate (1 - specificity)')
plt.ylabel('True Positive Rate (sensitivity)')
plt.title('ROC - Quadrilátero Ferrífero (QF)')
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# ## Making susceptibility maps with our trained classifiers

# %% [markdown]
# Predicting probability with trained ANN classifier

# %%
result_ann = stack.predict_proba(model_ann)

# %%
result_ann.plot()
plt.show()

# %%
result_ann.write(r"probability_ann_QF.tif")
# Out:
# Raster Object Containing 2 Layers
#     attribute                                             values
# 0       names                                   [prob_0, prob_1]
# 1       files   [probability_ann_QF.tif, probability_ann_QF.tif]
# 2        rows                                               1369
# 3        cols                                               1502
# 4         res                                       (12.5, 12.5)
# 5  nodatavals  [-3.4028234663852886e+38, -3.4028234663852886e...

# %% [markdown]
# Predicting probability with trained RF classifier

# %%
result_rf = stack.predict_proba(model_rf)

# %% [markdown]
# Plotting probabilities

# %%
result_rf.plot()
plt.show()

# %% [markdown]
# Saving the result as a .tif file

# %%
result_rf.write(r"probability_rf_QF.tif")
# Out:
# Raster Object Containing 2 Layers
#     attribute                                             values
# 0       names                                   [prob_0, prob_1]
# 1       files     [probability_rf_QF.tif, probability_rf_QF.tif]
# 2        rows                                               1369
# 3        cols                                               1502
# 4         res                                       (12.5, 12.5)
# 5  nodatavals  [-3.4028234663852886e+38, -3.4028234663852886e...

# %% [markdown]
# The end
